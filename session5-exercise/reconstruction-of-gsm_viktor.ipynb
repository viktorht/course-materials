# %% [markdown]
# # Reconstruction of genome-scale metabolic models

# %% [markdown]
# In the following exercise you are going to:
#
# * Reconstruct a draft of a genome-scale metabolic model using [carveme](https://github.com/cdanielmachado/carveme).
# * Analyze its characteristics (number of reactions, metabolites and genes; predicted growth rate etc.).
# * Validate your model using [memote](https://memote.io/).
# * Validate three other models of your choice (use Pubmed or Google Scholar to find publications of GSMs and then download them from the supplementary materials if available) a compare their quality metrics also with the model that you reconstructed.

# %% [markdown]
# ***
# **A.**
# Use [carveme](https://github.com/cdanielmachado/carveme) to generate a draft reconstruction for a bacterium of your choice.
#
# For example,
#
#     carve --refseq GCF_000166295.1 --output Marinobacter-adhaerens-HP15.xml --gapfill LB --init LB
#
# will generate a GSM for the bacterium *Marinobacter adhaerens* HP15 by accessing its [sequence](https://www.ncbi.nlm.nih.gov/nuccore/NC_017506.1) on [RefSeq](https://www.ncbi.nlm.nih.gov/refseq/) (`GCF_000166295.1` is its RefSeq accession number). After "carving" out a model from the universal reaction model, carveme will gap-fill the model to be able to grow on rich medium (`--gapfil LB`) and initialize the final model with that medium (`--init LB`). The final model is writing to a file named `Marinobacter-adhaerens-HP15.xml` (`--output Marinobacter-adhaerens-HP15.xml`).
#
# Hints:
# * You can find carveme's documentation [here](https://carveme.readthedocs.io/en/latest/usage.html).
# * You can excecute command line commandos (e.g. `carve`) in Jupyter notebook by prepending them with a `!` here in a code cell.

# %% [markdown]
# As an example, let's reconstruct a draft GSM for [*Marinobacter adhaerens HP15*](https://www.ncbi.nlm.nih.gov/assembly/GCF_000166295.1) (this should take a few minutes).

# %%
# %%time
# !carve --refseq GCF_000166295.1 --output Marinobacter-adhaerens-HP15-LB.xml --gapfill LB --init LB
# Out:
# Running diamond for the first time, please wait while we build the internal database...
# diamond v0.9.14.115 | by Benjamin Buchfink <buchfink@gmail.com>
# Licensed under the GNU AGPL <https://www.gnu.org/licenses/agpl.txt>
# Check http://github.com/bbuchfink/diamond for updates.
#
# #CPU threads: 8
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Database file: /Users/s143838/.pyenv/versions/anaconda3-2020.07/envs/carveme_env/lib/python3.6/site-packages/carveme/data/generated/bigg_proteins.faa
# Opening the database file...  [0.001324s]
# Loading sequences...  [0.088402s]
# Masking sequences...  [0.604364s]
# Writing sequences...  [0.094553s]
# Loading sequences...  [1.9e-05s]
# Writing trailer...  [0.002401s]
# Closing the input file...  [4.1e-05s]
# Closing the database file...  [0.000328s]
# Processed 26727 sequences, 11170577 letters.
# Total time = 0.791755s
# CPU times: user 1.01 s, sys: 333 ms, total: 1.34 s
# Wall time: 1min 11s

# %% [markdown]
# ***
# **B.**
# Try to answer the following questions.
#
# * How many reactions, metabolites and genes does the model contain?
# * What is the percentage of genes covered?
# * How fast does your model/organism grow?
# * What is the predicted growth rate if you gap-fill the model based on a minimal M9 glucose medium (`M9` instead of `LB`)
#
# Hints:
# * You can use `cobra.io.read_sbml_model` to load your model (see also previous exercise)
# * Reactions, metabolites and genes are accessible via `model.reactions`, `model.metabolites` and `model.genes` (see also previous exercise).
# * You can simulate the model by running model.optimize() (the objective value corresponds to $\mu_{max}$)
# * You can look at the medium of a model by running `model.medium`. This will return a dictionary of all the exchange reactions that enable uptable and the bound that has been set on that uptake

# %%
# For some reason im not able install the cobra package in my conda env. Thus, a fix maybe to use carveme only in command line and use the regular venv to analyse the model
from cobra.io import read_sbml_model
model = read_sbml_model('Marinobacter-adhaerens-HP15-LB.xml')

# %%
model
# Out:
# <Model Marinobacter_adhaerens_HP15_LB at 0x109448dc0>

# %%
model.optimize()
# Out:
# <Solution 0.903 at 0x12fea84f0>

# %% [markdown]
# Thus, maximum growth rate is 0.903

# %% [markdown]
# Running the following command in the carveme env in the terminal
# `carve --refseq GCF_000166295.1 --output Marinobacter-adhaerens-HP15-M9.xml --gapfill M9 --init M9`

# %%
model_m9 = read_sbml_model('Marinobacter-adhaerens-HP15-M9.xml')
model_m9
# Out:
# <Model Marinobacter_adhaerens_HP15_M9 at 0x12fea8d00>

# %%
model_m9.optimize()
model_m9.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 0.7811639316021279</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.004066</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.004066</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>7.812E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.0005538</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.01134</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.1525</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.006777</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>0.0005398</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>8.747</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.7703</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.1958</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.0002664</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4hba_e</td>
#       <td>EX_4hba_e</td>
#       <td>-0.0001742</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-26.67</td>
#       <td>1</td>
#       <td>99.99%</td>
#     </tr>
#     <tr>
#       <td>for_e</td>
#       <td>EX_for_e</td>
#       <td>-0.001646</td>
#       <td>1</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>h2_e</td>
#       <td>EX_h2_e</td>
#       <td>-39.19</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-18.31</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ***
# **C.**
#
# You can generate a report for a model with memote by running
#
#     memote report snapshot model.xml
#
# In the interest of time we're going to skip a few more computationally demanding tests and also write .
#
#     !memote report snapshot --skip test_stoichiometric_consistency \
#         --skip test_find_metabolites_not_produced_with_open_bounds \
#         --skip test_find_metabolites_not_consumed_with_open_bounds Marinobacter-adhaerens-HP15-LB.xml --filename Marinobacter-adhaerens-HP15-LB.html
#
# This will take a few minutes (depending on your model's size and the computational load on the Jupyter Classroom) and generate a file called `index.html` that contains the report. You can double click it in the file bwYou can continue to **D.** while you're waiting for the result.

# %% [markdown]
# You can adapt the following to match you're model.

# %%
# %%time
# !memote report snapshot --skip test_stoichiometric_consistency \
    --skip test_find_metabolites_not_produced_with_open_bounds \
    --skip test_find_metabolites_not_consumed_with_open_bounds Marinobacter-adhaerens-HP15-LB.xml --filename Marinobacter-adhaerens-HP15-LB.html
# Out:
# zsh:1: command not found: memote
# CPU times: user 5.02 ms, sys: 19.7 ms, total: 24.7 ms
# Wall time: 166 ms

# %% [markdown]
# ***
# **D.**
# Upload three models that you found in literature and test them with memote. Compare how different quality metrics vary between those models and also the model that you constructed with carveme.

# %%
model_yeast76 = read_sbml_model('yeast_7.6/yeast_7.6.xml')
model_yeast76
# Out:
# Loading SBML model without fbc:strict="true"
# Loading SBML with fbc-v1 (models should be encoded using fbc-v2)
# Adding exchange reaction EX_s_1656 with default bounds for boundary metabolite: s_1656.
# Adding exchange reaction EX_s_1657 with default bounds for boundary metabolite: s_1657.
# Adding exchange reaction EX_s_1658 with default bounds for boundary metabolite: s_1658.
# Adding exchange reaction EX_s_1659 with default bounds for boundary metabolite: s_1659.
# Adding exchange reaction EX_s_1660 with default bounds for boundary metabolite: s_1660.
# Adding exchange reaction EX_s_1661 with default bounds for boundary metabolite: s_1661.
# Adding exchange reaction EX_s_1662 with default bounds for boundary metabolite: s_1662.
# Adding exchange reaction EX_s_1663 with default bounds for boundary metabolite: s_1663.
# Adding exchange reaction EX_s_1664 with default bounds for boundary metabolite: s_1664.
# Adding exchange reaction EX_s_1665 with default bounds for boundary metabolite: s_1665.
# Adding exchange reaction EX_s_1666 with default bounds for boundary metabolite: s_1666.
# Adding exchange reaction EX_s_1667 with default bounds for boundary metabolite: s_1667.
# Adding exchange reaction EX_s_1668 with default bounds for boundary metabolite: s_1668.
# Adding exchange reaction EX_s_1669 with default bounds for boundary metabolite: s_1669.
# Adding exchange reaction EX_s_1670 with default bounds for boundary metabolite: s_1670.
# Adding exchange reaction EX_s_1672 with default bounds for boundary metabolite: s_1672.
# Adding exchange reaction EX_s_1673 with default bounds for boundary metabolite: s_1673.
# Adding exchange reaction EX_s_1674 with default bounds for boundary metabolite: s_1674.
# Adding exchange reaction EX_s_1675 with default bounds for boundary metabolite: s_1675.
# Adding exchange reaction EX_s_1676 with default bounds for boundary metabolite: s_1676.
# Adding exchange reaction EX_s_1677 with default bounds for boundary metabolite: s_1677.
# Adding exchange reaction EX_s_1678 with default bounds for boundary metabolite: s_1678.
# Adding exchange reaction EX_s_1679 with default bounds for boundary metabolite: s_1679.
# Adding exchange reaction EX_s_1680 with default bounds for boundary metabolite: s_1680.
# Adding exchange reaction EX_s_1681 with default bounds for boundary metabolite: s_1681.
# Adding exchange reaction EX_s_1682 with default bounds for boundary metabolite: s_1682.
# Adding exchange reaction EX_s_1683 with default bounds for boundary metabolite: s_1683.
# Adding exchange reaction EX_s_1684 with default bounds for boundary metabolite: s_1684.
# Adding exchange reaction EX_s_1685 with default bounds for boundary metabolite: s_1685.
# Adding exchange reaction EX_s_1686 with default bounds for boundary metabolite: s_1686.
# Adding exchange reaction EX_s_1687 with default bounds for boundary metabolite: s_1687.
# Adding exchange reaction EX_s_1688 with default bounds for boundary metabolite: s_1688.
# Adding exchange reaction EX_s_1689 with default bounds for boundary metabolite: s_1689.
# Adding exchange reaction EX_s_1690 with default bounds for boundary metabolite: s_1690.
# Adding exchange reaction EX_s_1691 with default bounds for boundary metabolite: s_1691.
# Adding exchange reaction EX_s_1692 with default bounds for boundary metabolite: s_1692.
# Adding exchange reaction EX_s_1693 with default bounds for boundary metabolite: s_1693.
# Adding exchange reaction EX_s_1694 with default bounds for boundary metabolite: s_1694.
# Adding exchange reaction EX_s_1695 with default bounds for boundary metabolite: s_1695.
# Adding exchange reaction EX_s_1696 with default bounds for boundary metabolite: s_1696.
# Adding exchange reaction EX_s_1697 with default bounds for boundary metabolite: s_1697.
# Adding exchange reaction EX_s_1698 with default bounds for boundary metabolite: s_1698.
# Adding exchange reaction EX_s_1699 with default bounds for boundary metabolite: s_1699.
# Adding exchange reaction EX_s_1700 with default bounds for boundary metabolite: s_1700.
# Adding exchange reaction EX_s_1701 with default bounds for boundary metabolite: s_1701.
# Adding exchange reaction EX_s_1702 with default bounds for boundary metabolite: s_1702.
# Adding exchange reaction EX_s_1703 with default bounds for boundary metabolite: s_1703.
# Adding exchange reaction EX_s_1704 with default bounds for boundary metabolite: s_1704.
# Adding exchange reaction EX_s_1705 with default bounds for boundary metabolite: s_1705.
# Adding exchange reaction EX_s_1706 with default bounds for boundary metabolite: s_1706.
# Adding exchange reaction EX_s_1707 with default bounds for boundary metabolite: s_1707.
# Adding exchange reaction EX_s_1708 with default bounds for boundary metabolite: s_1708.
# Adding exchange reaction EX_s_1709 with default bounds for boundary metabolite: s_1709.
# Adding exchange reaction EX_s_1710 with default bounds for boundary metabolite: s_1710.
# Adding exchange reaction EX_s_1711 with default bounds for boundary metabolite: s_1711.
# Adding exchange reaction EX_s_1712 with default bounds for boundary metabolite: s_1712.
# Adding exchange reaction EX_s_1713 with default bounds for boundary metabolite: s_1713.
# Adding exchange reaction EX_s_1714 with default bounds for boundary metabolite: s_1714.
# Adding exchange reaction EX_s_1715 with default bounds for boundary metabolite: s_1715.
# Adding exchange reaction EX_s_1716 with default bounds for boundary metabolite: s_1716.
# Adding exchange reaction EX_s_1717 with default bounds for boundary metabolite: s_1717.
# Adding exchange reaction EX_s_1719 with default bounds for boundary metabolite: s_1719.
# Adding exchange reaction EX_s_1720 with default bounds for boundary metabolite: s_1720.
# Adding exchange reaction EX_s_1721 with default bounds for boundary metabolite: s_1721.
# Adding exchange reaction EX_s_1722 with default bounds for boundary metabolite: s_1722.
# Adding exchange reaction EX_s_1723 with default bounds for boundary metabolite: s_1723.
# Adding exchange reaction EX_s_1725 with default bounds for boundary metabolite: s_1725.
# Adding exchange reaction EX_s_1726 with default bounds for boundary metabolite: s_1726.
# Adding exchange reaction EX_s_1727 with default bounds for boundary metabolite: s_1727.
# Adding exchange reaction EX_s_1728 with default bounds for boundary metabolite: s_1728.
# Adding exchange reaction EX_s_1729 with default bounds for boundary metabolite: s_1729.
# Adding exchange reaction EX_s_1730 with default bounds for boundary metabolite: s_1730.
# Adding exchange reaction EX_s_1731 with default bounds for boundary metabolite: s_1731.
# Adding exchange reaction EX_s_1732 with default bounds for boundary metabolite: s_1732.
# Adding exchange reaction EX_s_1733 with default bounds for boundary metabolite: s_1733.
# Adding exchange reaction EX_s_1734 with default bounds for boundary metabolite: s_1734.
# Adding exchange reaction EX_s_1735 with default bounds for boundary metabolite: s_1735.
# Adding exchange reaction EX_s_1736 with default bounds for boundary metabolite: s_1736.
# Adding exchange reaction EX_s_1737 with default bounds for boundary metabolite: s_1737.
# Adding exchange reaction EX_s_1738 with default bounds for boundary metabolite: s_1738.
# Adding exchange reaction EX_s_1739 with default bounds for boundary metabolite: s_1739.
# Adding exchange reaction EX_s_1740 with default bounds for boundary metabolite: s_1740.
# Adding exchange reaction EX_s_1741 with default bounds for boundary metabolite: s_1741.
# Adding exchange reaction EX_s_1742 with default bounds for boundary metabolite: s_1742.
# Adding exchange reaction EX_s_1743 with default bounds for boundary metabolite: s_1743.
# Adding exchange reaction EX_s_1744 with default bounds for boundary metabolite: s_1744.
# Adding exchange reaction EX_s_1745 with default bounds for boundary metabolite: s_1745.
# Adding exchange reaction EX_s_1746 with default bounds for boundary metabolite: s_1746.
# Adding exchange reaction EX_s_1747 with default bounds for boundary metabolite: s_1747.
# Adding exchange reaction EX_s_1748 with default bounds for boundary metabolite: s_1748.
# Adding exchange reaction EX_s_1749 with default bounds for boundary metabolite: s_1749.
# Adding exchange reaction EX_s_1750 with default bounds for boundary metabolite: s_1750.
# Adding exchange reaction EX_s_1751 with default bounds for boundary metabolite: s_1751.
# Adding exchange reaction EX_s_1752 with default bounds for boundary metabolite: s_1752.
# Adding exchange reaction EX_s_1753 with default bounds for boundary metabolite: s_1753.
# Adding exchange reaction EX_s_1754 with default bounds for boundary metabolite: s_1754.
# Adding exchange reaction EX_s_1755 with default bounds for boundary metabolite: s_1755.
# Adding exchange reaction EX_s_1756 with default bounds for boundary metabolite: s_1756.
# Adding exchange reaction EX_s_1757 with default bounds for boundary metabolite: s_1757.
# Adding exchange reaction EX_s_1758 with default bounds for boundary metabolite: s_1758.
# Adding exchange reaction EX_s_1759 with default bounds for boundary metabolite: s_1759.
# Adding exchange reaction EX_s_1760 with default bounds for boundary metabolite: s_1760.
# Adding exchange reaction EX_s_1761 with default bounds for boundary metabolite: s_1761.
# Adding exchange reaction EX_s_1762 with default bounds for boundary metabolite: s_1762.
# Adding exchange reaction EX_s_1763 with default bounds for boundary metabolite: s_1763.
# Adding exchange reaction EX_s_1764 with default bounds for boundary metabolite: s_1764.
# Adding exchange reaction EX_s_1765 with default bounds for boundary metabolite: s_1765.
# Adding exchange reaction EX_s_1766 with default bounds for boundary metabolite: s_1766.
# Adding exchange reaction EX_s_1767 with default bounds for boundary metabolite: s_1767.
# Adding exchange reaction EX_s_1768 with default bounds for boundary metabolite: s_1768.
# Adding exchange reaction EX_s_1769 with default bounds for boundary metabolite: s_1769.
# Adding exchange reaction EX_s_1770 with default bounds for boundary metabolite: s_1770.
# Adding exchange reaction EX_s_1771 with default bounds for boundary metabolite: s_1771.
# Adding exchange reaction EX_s_1774 with default bounds for boundary metabolite: s_1774.
# Adding exchange reaction EX_s_1776 with default bounds for boundary metabolite: s_1776.
# Adding exchange reaction EX_s_1779 with default bounds for boundary metabolite: s_1779.
# Adding exchange reaction EX_s_1781 with default bounds for boundary metabolite: s_1781.
# Adding exchange reaction EX_s_1782 with default bounds for boundary metabolite: s_1782.
# Adding exchange reaction EX_s_1783 with default bounds for boundary metabolite: s_1783.
# Adding exchange reaction EX_s_1785 with default bounds for boundary metabolite: s_1785.
# Adding exchange reaction EX_s_1786 with default bounds for boundary metabolite: s_1786.
# Adding exchange reaction EX_s_1787 with default bounds for boundary metabolite: s_1787.
# Adding exchange reaction EX_s_1788 with default bounds for boundary metabolite: s_1788.
# Adding exchange reaction EX_s_1789 with default bounds for boundary metabolite: s_1789.
# Adding exchange reaction EX_s_1790 with default bounds for boundary metabolite: s_1790.
# Adding exchange reaction EX_s_1791 with default bounds for boundary metabolite: s_1791.
# Adding exchange reaction EX_s_1792 with default bounds for boundary metabolite: s_1792.
# Adding exchange reaction EX_s_1793 with default bounds for boundary metabolite: s_1793.
# Adding exchange reaction EX_s_1797 with default bounds for boundary metabolite: s_1797.
# Adding exchange reaction EX_s_1798 with default bounds for boundary metabolite: s_1798.
# Adding exchange reaction EX_s_1799 with default bounds for boundary metabolite: s_1799.
# Adding exchange reaction EX_s_1800 with default bounds for boundary metabolite: s_1800.
# Adding exchange reaction EX_s_1801 with default bounds for boundary metabolite: s_1801.
# Adding exchange reaction EX_s_1802 with default bounds for boundary metabolite: s_1802.
# Adding exchange reaction EX_s_1803 with default bounds for boundary metabolite: s_1803.
# Adding exchange reaction EX_s_1804 with default bounds for boundary metabolite: s_1804.
# Adding exchange reaction EX_s_1805 with default bounds for boundary metabolite: s_1805.
# Adding exchange reaction EX_s_1806 with default bounds for boundary metabolite: s_1806.
# Adding exchange reaction EX_s_1807 with default bounds for boundary metabolite: s_1807.
# Adding exchange reaction EX_s_1808 with default bounds for boundary metabolite: s_1808.
# Adding exchange reaction EX_s_1809 with default bounds for boundary metabolite: s_1809.
# Adding exchange reaction EX_s_1810 with default bounds for boundary metabolite: s_1810.
# Adding exchange reaction EX_s_1811 with default bounds for boundary metabolite: s_1811.
# Adding exchange reaction EX_s_1812 with default bounds for boundary metabolite: s_1812.
# Adding exchange reaction EX_s_1813 with default bounds for boundary metabolite: s_1813.
# Adding exchange reaction EX_s_1814 with default bounds for boundary metabolite: s_1814.
# Adding exchange reaction EX_s_1815 with default bounds for boundary metabolite: s_1815.
# Adding exchange reaction EX_s_1817 with default bounds for boundary metabolite: s_1817.
# Adding exchange reaction EX_s_1818 with default bounds for boundary metabolite: s_1818.
# Adding exchange reaction EX_s_1819 with default bounds for boundary metabolite: s_1819.
# Adding exchange reaction EX_s_1820 with default bounds for boundary metabolite: s_1820.
# Adding exchange reaction EX_s_1821 with default bounds for boundary metabolite: s_1821.
# Adding exchange reaction EX_s_1822 with default bounds for boundary metabolite: s_1822.
# Adding exchange reaction EX_s_1823 with default bounds for boundary metabolite: s_1823.
# Adding exchange reaction EX_s_1824 with default bounds for boundary metabolite: s_1824.
# Adding exchange reaction EX_s_1825 with default bounds for boundary metabolite: s_1825.
# Adding exchange reaction EX_s_2761 with default bounds for boundary metabolite: s_2761.
# Adding exchange reaction EX_e_0001 with default bounds for boundary metabolite: e_0001.
# Adding exchange reaction EX_e_0002 with default bounds for boundary metabolite: e_0002.
# Adding exchange reaction EX_e_0003 with default bounds for boundary metabolite: e_0003.
# Adding exchange reaction EX_e_0004 with default bounds for boundary metabolite: e_0004.
# Adding exchange reaction EX_e_0005 with default bounds for boundary metabolite: e_0005.
# Adding exchange reaction EX_e_0006 with default bounds for boundary metabolite: e_0006.
# Adding exchange reaction EX_e_0007 with default bounds for boundary metabolite: e_0007.
# Adding exchange reaction EX_e_0008 with default bounds for boundary metabolite: e_0008.
# Adding exchange reaction EX_e_0009 with default bounds for boundary metabolite: e_0009.
# Adding exchange reaction EX_e_0010 with default bounds for boundary metabolite: e_0010.
# Adding exchange reaction EX_e_0011 with default bounds for boundary metabolite: e_0011.
# Adding exchange reaction EX_e_0012 with default bounds for boundary metabolite: e_0012.
# Adding exchange reaction EX_e_0013 with default bounds for boundary metabolite: e_0013.
# Adding exchange reaction EX_e_0014 with default bounds for boundary metabolite: e_0014.
# Adding exchange reaction EX_e_0015 with default bounds for boundary metabolite: e_0015.
# Adding exchange reaction EX_e_0016 with default bounds for boundary metabolite: e_0016.
# Adding exchange reaction EX_e_0017 with default bounds for boundary metabolite: e_0017.
# Adding exchange reaction EX_e_0018 with default bounds for boundary metabolite: e_0018.
# Adding exchange reaction EX_e_0019 with default bounds for boundary metabolite: e_0019.
# Adding exchange reaction EX_e_0021 with default bounds for boundary metabolite: e_0021.
# Adding exchange reaction EX_e_0023 with default bounds for boundary metabolite: e_0023.
# Adding exchange reaction EX_e_0024 with default bounds for boundary metabolite: e_0024.
# Adding exchange reaction EX_e_0025 with default bounds for boundary metabolite: e_0025.
# Adding exchange reaction EX_e_0026 with default bounds for boundary metabolite: e_0026.
# Adding exchange reaction EX_e_0027 with default bounds for boundary metabolite: e_0027.
# Adding exchange reaction EX_e_0028 with default bounds for boundary metabolite: e_0028.
# Adding exchange reaction EX_e_0029 with default bounds for boundary metabolite: e_0029.
# Adding exchange reaction EX_e_0030 with default bounds for boundary metabolite: e_0030.
# Adding exchange reaction EX_e_0031 with default bounds for boundary metabolite: e_0031.
# Adding exchange reaction EX_e_0032 with default bounds for boundary metabolite: e_0032.
# Adding exchange reaction EX_e_0033 with default bounds for boundary metabolite: e_0033.
# Adding exchange reaction EX_e_0034 with default bounds for boundary metabolite: e_0034.
# Adding exchange reaction EX_e_0035 with default bounds for boundary metabolite: e_0035.
# Adding exchange reaction EX_e_0036 with default bounds for boundary metabolite: e_0036.
# Adding exchange reaction EX_e_0037 with default bounds for boundary metabolite: e_0037.
# Adding exchange reaction EX_e_0038 with default bounds for boundary metabolite: e_0038.
# Adding exchange reaction EX_e_0039 with default bounds for boundary metabolite: e_0039.
# Adding exchange reaction EX_e_0040 with default bounds for boundary metabolite: e_0040.
# Adding exchange reaction EX_e_0041 with default bounds for boundary metabolite: e_0041.
# Adding exchange reaction EX_e_0042 with default bounds for boundary metabolite: e_0042.
# Adding exchange reaction EX_e_0043 with default bounds for boundary metabolite: e_0043.
# Adding exchange reaction EX_e_0044 with default bounds for boundary metabolite: e_0044.
# Adding exchange reaction EX_e_0047 with default bounds for boundary metabolite: e_0047.
# Adding exchange reaction EX_e_0048 with default bounds for boundary metabolite: e_0048.
# Adding exchange reaction EX_e_0049 with default bounds for boundary metabolite: e_0049.
# Adding exchange reaction EX_e_0050 with default bounds for boundary metabolite: e_0050.
# Adding exchange reaction EX_e_0051 with default bounds for boundary metabolite: e_0051.
# Adding exchange reaction EX_e_0054 with default bounds for boundary metabolite: e_0054.
# Adding exchange reaction EX_e_0055 with default bounds for boundary metabolite: e_0055.
# Adding exchange reaction EX_e_0056 with default bounds for boundary metabolite: e_0056.
# Adding exchange reaction EX_e_0057 with default bounds for boundary metabolite: e_0057.
# Adding exchange reaction EX_e_0058 with default bounds for boundary metabolite: e_0058.
# Adding exchange reaction EX_e_0059 with default bounds for boundary metabolite: e_0059.
# Adding exchange reaction EX_e_0060 with default bounds for boundary metabolite: e_0060.
# Adding exchange reaction EX_e_0061 with default bounds for boundary metabolite: e_0061.
# Adding exchange reaction EX_e_0062 with default bounds for boundary metabolite: e_0062.
# Adding exchange reaction EX_e_0063 with default bounds for boundary metabolite: e_0063.
# Adding exchange reaction EX_e_0064 with default bounds for boundary metabolite: e_0064.
# Adding exchange reaction EX_e_0065 with default bounds for boundary metabolite: e_0065.
# Adding exchange reaction EX_e_0066 with default bounds for boundary metabolite: e_0066.
# Adding exchange reaction EX_e_0067 with default bounds for boundary metabolite: e_0067.
# Adding exchange reaction EX_e_0068 with default bounds for boundary metabolite: e_0068.
# Adding exchange reaction EX_e_0069 with default bounds for boundary metabolite: e_0069.
# Adding exchange reaction EX_e_0070 with default bounds for boundary metabolite: e_0070.
# Adding exchange reaction EX_e_0071 with default bounds for boundary metabolite: e_0071.
# Adding exchange reaction EX_e_0073 with default bounds for boundary metabolite: e_0073.
# Adding exchange reaction EX_e_0074 with default bounds for boundary metabolite: e_0074.
# Adding exchange reaction EX_e_0075 with default bounds for boundary metabolite: e_0075.
# Adding exchange reaction EX_e_0076 with default bounds for boundary metabolite: e_0076.
# Adding exchange reaction EX_e_0077 with default bounds for boundary metabolite: e_0077.
# Adding exchange reaction EX_e_0078 with default bounds for boundary metabolite: e_0078.
# Adding exchange reaction EX_e_0079 with default bounds for boundary metabolite: e_0079.
# Adding exchange reaction EX_e_0080 with default bounds for boundary metabolite: e_0080.
# Adding exchange reaction EX_e_0081 with default bounds for boundary metabolite: e_0081.
# Adding exchange reaction EX_e_0082 with default bounds for boundary metabolite: e_0082.
# Adding exchange reaction EX_e_0083 with default bounds for boundary metabolite: e_0083.
# Adding exchange reaction EX_e_0084 with default bounds for boundary metabolite: e_0084.
# Adding exchange reaction EX_e_0085 with default bounds for boundary metabolite: e_0085.
# Adding exchange reaction EX_e_0086 with default bounds for boundary metabolite: e_0086.
# Adding exchange reaction EX_e_0087 with default bounds for boundary metabolite: e_0087.
# Adding exchange reaction EX_e_0088 with default bounds for boundary metabolite: e_0088.
# Adding exchange reaction EX_e_0089 with default bounds for boundary metabolite: e_0089.
# Adding exchange reaction EX_e_0090 with default bounds for boundary metabolite: e_0090.
# Adding exchange reaction EX_e_0091 with default bounds for boundary metabolite: e_0091.
# Adding exchange reaction EX_e_0092 with default bounds for boundary metabolite: e_0092.
# Adding exchange reaction EX_e_0093 with default bounds for boundary metabolite: e_0093.
# Adding exchange reaction EX_e_0094 with default bounds for boundary metabolite: e_0094.
# Adding exchange reaction EX_e_0095 with default bounds for boundary metabolite: e_0095.
# Adding exchange reaction EX_e_0096 with default bounds for boundary metabolite: e_0096.
# Adding exchange reaction EX_e_0097 with default bounds for boundary metabolite: e_0097.
# Adding exchange reaction EX_e_0098 with default bounds for boundary metabolite: e_0098.
# Adding exchange reaction EX_e_0100 with default bounds for boundary metabolite: e_0100.
# Adding exchange reaction EX_e_0101 with default bounds for boundary metabolite: e_0101.
# Adding exchange reaction EX_e_0102 with default bounds for boundary metabolite: e_0102.
# Adding exchange reaction EX_e_0103 with default bounds for boundary metabolite: e_0103.
# Adding exchange reaction EX_e_0104 with default bounds for boundary metabolite: e_0104.
# Adding exchange reaction EX_e_0105 with default bounds for boundary metabolite: e_0105.
# Adding exchange reaction EX_e_0106 with default bounds for boundary metabolite: e_0106.
# Adding exchange reaction EX_e_0107 with default bounds for boundary metabolite: e_0107.
# Adding exchange reaction EX_e_0108 with default bounds for boundary metabolite: e_0108.
# Adding exchange reaction EX_e_0109 with default bounds for boundary metabolite: e_0109.
# Adding exchange reaction EX_e_0110 with default bounds for boundary metabolite: e_0110.
# Adding exchange reaction EX_e_0111 with default bounds for boundary metabolite: e_0111.
# Adding exchange reaction EX_e_0112 with default bounds for boundary metabolite: e_0112.
# Adding exchange reaction EX_e_0113 with default bounds for boundary metabolite: e_0113.
# Adding exchange reaction EX_e_0114 with default bounds for boundary metabolite: e_0114.
# Adding exchange reaction EX_e_0115 with default bounds for boundary metabolite: e_0115.
# Adding exchange reaction EX_e_0116 with default bounds for boundary metabolite: e_0116.
# Adding exchange reaction EX_e_0119 with default bounds for boundary metabolite: e_0119.
# Adding exchange reaction EX_e_0120 with default bounds for boundary metabolite: e_0120.
# Adding exchange reaction EX_e_0122 with default bounds for boundary metabolite: e_0122.
# Adding exchange reaction EX_e_0123 with default bounds for boundary metabolite: e_0123.
# Adding exchange reaction EX_e_0124 with default bounds for boundary metabolite: e_0124.
# Adding exchange reaction EX_e_0125 with default bounds for boundary metabolite: e_0125.
# Adding exchange reaction EX_e_0126 with default bounds for boundary metabolite: e_0126.
# Adding exchange reaction EX_e_0127 with default bounds for boundary metabolite: e_0127.
# Adding exchange reaction EX_e_0129 with default bounds for boundary metabolite: e_0129.
# Adding exchange reaction EX_e_0130 with default bounds for boundary metabolite: e_0130.
# Adding exchange reaction EX_e_0131 with default bounds for boundary metabolite: e_0131.
# Adding exchange reaction EX_e_0133 with default bounds for boundary metabolite: e_0133.
# Adding exchange reaction EX_e_0134 with default bounds for boundary metabolite: e_0134.
# Adding exchange reaction EX_e_0135 with default bounds for boundary metabolite: e_0135.
# Adding exchange reaction EX_e_0136 with default bounds for boundary metabolite: e_0136.
# Adding exchange reaction EX_e_0137 with default bounds for boundary metabolite: e_0137.
# Adding exchange reaction EX_e_0138 with default bounds for boundary metabolite: e_0138.
# Adding exchange reaction EX_e_0139 with default bounds for boundary metabolite: e_0139.
# Adding exchange reaction EX_e_0140 with default bounds for boundary metabolite: e_0140.
# Adding exchange reaction EX_e_0141 with default bounds for boundary metabolite: e_0141.
# Adding exchange reaction EX_e_0142 with default bounds for boundary metabolite: e_0142.
# Adding exchange reaction EX_e_0143 with default bounds for boundary metabolite: e_0143.
# Adding exchange reaction EX_e_0144 with default bounds for boundary metabolite: e_0144.
# Adding exchange reaction EX_e_0145 with default bounds for boundary metabolite: e_0145.
# Adding exchange reaction EX_e_0146 with default bounds for boundary metabolite: e_0146.
# Adding exchange reaction EX_e_0147 with default bounds for boundary metabolite: e_0147.
# Adding exchange reaction EX_e_0149 with default bounds for boundary metabolite: e_0149.
# Adding exchange reaction EX_e_0150 with default bounds for boundary metabolite: e_0150.
# Adding exchange reaction EX_e_0151 with default bounds for boundary metabolite: e_0151.
# Adding exchange reaction EX_e_0152 with default bounds for boundary metabolite: e_0152.
# Adding exchange reaction EX_e_0153 with default bounds for boundary metabolite: e_0153.
# Adding exchange reaction EX_e_0154 with default bounds for boundary metabolite: e_0154.
# Adding exchange reaction EX_e_0155 with default bounds for boundary metabolite: e_0155.
# Adding exchange reaction EX_e_0156 with default bounds for boundary metabolite: e_0156.
# Adding exchange reaction EX_e_0157 with default bounds for boundary metabolite: e_0157.
# Adding exchange reaction EX_e_0158 with default bounds for boundary metabolite: e_0158.
# Adding exchange reaction EX_e_0159 with default bounds for boundary metabolite: e_0159.
# Adding exchange reaction EX_e_0160 with default bounds for boundary metabolite: e_0160.
# Adding exchange reaction EX_e_0161 with default bounds for boundary metabolite: e_0161.
# Adding exchange reaction EX_e_0162 with default bounds for boundary metabolite: e_0162.
# Adding exchange reaction EX_e_0163 with default bounds for boundary metabolite: e_0163.
# Adding exchange reaction EX_e_0164 with default bounds for boundary metabolite: e_0164.
# Adding exchange reaction EX_e_0165 with default bounds for boundary metabolite: e_0165.
# Adding exchange reaction EX_e_0166 with default bounds for boundary metabolite: e_0166.
# Adding exchange reaction EX_e_0167 with default bounds for boundary metabolite: e_0167.
# Adding exchange reaction EX_e_0168 with default bounds for boundary metabolite: e_0168.
# Adding exchange reaction EX_e_0169 with default bounds for boundary metabolite: e_0169.
# Adding exchange reaction EX_e_0170 with default bounds for boundary metabolite: e_0170.
# Adding exchange reaction EX_e_0171 with default bounds for boundary metabolite: e_0171.
# Adding exchange reaction EX_e_0172 with default bounds for boundary metabolite: e_0172.
# Adding exchange reaction EX_e_0173 with default bounds for boundary metabolite: e_0173.
# Adding exchange reaction EX_e_0174 with default bounds for boundary metabolite: e_0174.
# Adding exchange reaction EX_e_0175 with default bounds for boundary metabolite: e_0175.
# Adding exchange reaction EX_e_0177 with default bounds for boundary metabolite: e_0177.
# Adding exchange reaction EX_e_0179 with default bounds for boundary metabolite: e_0179.
# Adding exchange reaction EX_e_0181 with default bounds for boundary metabolite: e_0181.
# Adding exchange reaction EX_e_0182 with default bounds for boundary metabolite: e_0182.
# Adding exchange reaction EX_e_0183 with default bounds for boundary metabolite: e_0183.
# Adding exchange reaction EX_e_0184 with default bounds for boundary metabolite: e_0184.
# Adding exchange reaction EX_e_0185 with default bounds for boundary metabolite: e_0185.
# Adding exchange reaction EX_e_0186 with default bounds for boundary metabolite: e_0186.
# Adding exchange reaction EX_e_0187 with default bounds for boundary metabolite: e_0187.
# Adding exchange reaction EX_e_0188 with default bounds for boundary metabolite: e_0188.
# Adding exchange reaction EX_e_0189 with default bounds for boundary metabolite: e_0189.
# Adding exchange reaction EX_e_0190 with default bounds for boundary metabolite: e_0190.
# Adding exchange reaction EX_e_0191 with default bounds for boundary metabolite: e_0191.
# Adding exchange reaction EX_e_0192 with default bounds for boundary metabolite: e_0192.
# Adding exchange reaction EX_e_0193 with default bounds for boundary metabolite: e_0193.
# Adding exchange reaction EX_e_0194 with default bounds for boundary metabolite: e_0194.
# Adding exchange reaction EX_e_0195 with default bounds for boundary metabolite: e_0195.
# Adding exchange reaction EX_e_0196 with default bounds for boundary metabolite: e_0196.
# Adding exchange reaction EX_e_0197 with default bounds for boundary metabolite: e_0197.
# Adding exchange reaction EX_e_0198 with default bounds for boundary metabolite: e_0198.
# Adding exchange reaction EX_e_0199 with default bounds for boundary metabolite: e_0199.
# Adding exchange reaction EX_e_0200 with default bounds for boundary metabolite: e_0200.
# Adding exchange reaction EX_e_0201 with default bounds for boundary metabolite: e_0201.
# Adding exchange reaction EX_e_0202 with default bounds for boundary metabolite: e_0202.
# Adding exchange reaction EX_e_0204 with default bounds for boundary metabolite: e_0204.
# Adding exchange reaction EX_e_0205 with default bounds for boundary metabolite: e_0205.
# Adding exchange reaction EX_e_0206 with default bounds for boundary metabolite: e_0206.
# Adding exchange reaction EX_e_0207 with default bounds for boundary metabolite: e_0207.
# Adding exchange reaction EX_e_0208 with default bounds for boundary metabolite: e_0208.
# Adding exchange reaction EX_e_0209 with default bounds for boundary metabolite: e_0209.
# Adding exchange reaction EX_e_0210 with default bounds for boundary metabolite: e_0210.
# Adding exchange reaction EX_e_0211 with default bounds for boundary metabolite: e_0211.
# Adding exchange reaction EX_e_0212 with default bounds for boundary metabolite: e_0212.
# Adding exchange reaction EX_e_0213 with default bounds for boundary metabolite: e_0213.
# Adding exchange reaction EX_e_0214 with default bounds for boundary metabolite: e_0214.
# Adding exchange reaction EX_e_0215 with default bounds for boundary metabolite: e_0215.
# Adding exchange reaction EX_e_0216 with default bounds for boundary metabolite: e_0216.
# Adding exchange reaction EX_e_0217 with default bounds for boundary metabolite: e_0217.
# Adding exchange reaction EX_e_0218 with default bounds for boundary metabolite: e_0218.
# Adding exchange reaction EX_e_0219 with default bounds for boundary metabolite: e_0219.
# Adding exchange reaction EX_e_0221 with default bounds for boundary metabolite: e_0221.
# Adding exchange reaction EX_e_0222 with default bounds for boundary metabolite: e_0222.
# Adding exchange reaction EX_e_0223 with default bounds for boundary metabolite: e_0223.
# Adding exchange reaction EX_e_0224 with default bounds for boundary metabolite: e_0224.
# Adding exchange reaction EX_e_0225 with default bounds for boundary metabolite: e_0225.
# Adding exchange reaction EX_e_0226 with default bounds for boundary metabolite: e_0226.
# Adding exchange reaction EX_e_0227 with default bounds for boundary metabolite: e_0227.
# Adding exchange reaction EX_e_0228 with default bounds for boundary metabolite: e_0228.
# Adding exchange reaction EX_e_0229 with default bounds for boundary metabolite: e_0229.
# Adding exchange reaction EX_e_0230 with default bounds for boundary metabolite: e_0230.
# Adding exchange reaction EX_e_0231 with default bounds for boundary metabolite: e_0231.
# Adding exchange reaction EX_e_0232 with default bounds for boundary metabolite: e_0232.
# Adding exchange reaction EX_e_0233 with default bounds for boundary metabolite: e_0233.
# Adding exchange reaction EX_e_0234 with default bounds for boundary metabolite: e_0234.
# Adding exchange reaction EX_e_0235 with default bounds for boundary metabolite: e_0235.
# Adding exchange reaction EX_e_0236 with default bounds for boundary metabolite: e_0236.
# Adding exchange reaction EX_e_0237 with default bounds for boundary metabolite: e_0237.
# Adding exchange reaction EX_e_0238 with default bounds for boundary metabolite: e_0238.
# Adding exchange reaction EX_e_0239 with default bounds for boundary metabolite: e_0239.
# Adding exchange reaction EX_e_0241 with default bounds for boundary metabolite: e_0241.
# Adding exchange reaction EX_e_0242 with default bounds for boundary metabolite: e_0242.
# Adding exchange reaction EX_e_0243 with default bounds for boundary metabolite: e_0243.
# Adding exchange reaction EX_e_0244 with default bounds for boundary metabolite: e_0244.
# Adding exchange reaction EX_e_0245 with default bounds for boundary metabolite: e_0245.
# Adding exchange reaction EX_e_0246 with default bounds for boundary metabolite: e_0246.
# Adding exchange reaction EX_e_0247 with default bounds for boundary metabolite: e_0247.
# Adding exchange reaction EX_e_0248 with default bounds for boundary metabolite: e_0248.
# Adding exchange reaction EX_e_0249 with default bounds for boundary metabolite: e_0249.
# Adding exchange reaction EX_e_0250 with default bounds for boundary metabolite: e_0250.
# Adding exchange reaction EX_e_0251 with default bounds for boundary metabolite: e_0251.
# Adding exchange reaction EX_e_0252 with default bounds for boundary metabolite: e_0252.
# Adding exchange reaction EX_e_0253 with default bounds for boundary metabolite: e_0253.
# Adding exchange reaction EX_e_0254 with default bounds for boundary metabolite: e_0254.
# Adding exchange reaction EX_e_0255 with default bounds for boundary metabolite: e_0255.
# Adding exchange reaction EX_e_0256 with default bounds for boundary metabolite: e_0256.
# Adding exchange reaction EX_e_0257 with default bounds for boundary metabolite: e_0257.
# Adding exchange reaction EX_e_0258 with default bounds for boundary metabolite: e_0258.
# Adding exchange reaction EX_e_0259 with default bounds for boundary metabolite: e_0259.
# Adding exchange reaction EX_e_0260 with default bounds for boundary metabolite: e_0260.
# Adding exchange reaction EX_e_0261 with default bounds for boundary metabolite: e_0261.
# Adding exchange reaction EX_e_0262 with default bounds for boundary metabolite: e_0262.
# Adding exchange reaction EX_e_0263 with default bounds for boundary metabolite: e_0263.
# Adding exchange reaction EX_e_0264 with default bounds for boundary metabolite: e_0264.
# Adding exchange reaction EX_e_0265 with default bounds for boundary metabolite: e_0265.
# Adding exchange reaction EX_e_0266 with default bounds for boundary metabolite: e_0266.
# Adding exchange reaction EX_e_0267 with default bounds for boundary metabolite: e_0267.
# Adding exchange reaction EX_e_0268 with default bounds for boundary metabolite: e_0268.
# Adding exchange reaction EX_e_0269 with default bounds for boundary metabolite: e_0269.
# Adding exchange reaction EX_e_0270 with default bounds for boundary metabolite: e_0270.
# Adding exchange reaction EX_e_0271 with default bounds for boundary metabolite: e_0271.
# Adding exchange reaction EX_e_0272 with default bounds for boundary metabolite: e_0272.
# Adding exchange reaction EX_e_0273 with default bounds for boundary metabolite: e_0273.
# Adding exchange reaction EX_e_0274 with default bounds for boundary metabolite: e_0274.
# Adding exchange reaction EX_e_0275 with default bounds for boundary metabolite: e_0275.
# Adding exchange reaction EX_e_0276 with default bounds for boundary metabolite: e_0276.
# Adding exchange reaction EX_e_0277 with default bounds for boundary metabolite: e_0277.
# Adding exchange reaction EX_e_0280 with default bounds for boundary metabolite: e_0280.
# Adding exchange reaction EX_e_0281 with default bounds for boundary metabolite: e_0281.
# Adding exchange reaction EX_e_0282 with default bounds for boundary metabolite: e_0282.
# Adding exchange reaction EX_e_0283 with default bounds for boundary metabolite: e_0283.
# Adding exchange reaction EX_e_0284 with default bounds for boundary metabolite: e_0284.
# Adding exchange reaction EX_e_0285 with default bounds for boundary metabolite: e_0285.
# Adding exchange reaction EX_e_0286 with default bounds for boundary metabolite: e_0286.
# Adding exchange reaction EX_e_0287 with default bounds for boundary metabolite: e_0287.
# Adding exchange reaction EX_e_0288 with default bounds for boundary metabolite: e_0288.
# Adding exchange reaction EX_e_0289 with default bounds for boundary metabolite: e_0289.
# Adding exchange reaction EX_e_0290 with default bounds for boundary metabolite: e_0290.
# Adding exchange reaction EX_e_0291 with default bounds for boundary metabolite: e_0291.
# Adding exchange reaction EX_e_0292 with default bounds for boundary metabolite: e_0292.
# Adding exchange reaction EX_e_0293 with default bounds for boundary metabolite: e_0293.
# Adding exchange reaction EX_e_0294 with default bounds for boundary metabolite: e_0294.
# Adding exchange reaction EX_e_0295 with default bounds for boundary metabolite: e_0295.
# Adding exchange reaction EX_e_0297 with default bounds for boundary metabolite: e_0297.
# Adding exchange reaction EX_e_0298 with default bounds for boundary metabolite: e_0298.
# Adding exchange reaction EX_e_0299 with default bounds for boundary metabolite: e_0299.
# Adding exchange reaction EX_e_0300 with default bounds for boundary metabolite: e_0300.
# Adding exchange reaction EX_e_0301 with default bounds for boundary metabolite: e_0301.
# Adding exchange reaction EX_e_0303 with default bounds for boundary metabolite: e_0303.
# Adding exchange reaction EX_e_0304 with default bounds for boundary metabolite: e_0304.
# Adding exchange reaction EX_e_0305 with default bounds for boundary metabolite: e_0305.
# Adding exchange reaction EX_e_0306 with default bounds for boundary metabolite: e_0306.
# Adding exchange reaction EX_e_0307 with default bounds for boundary metabolite: e_0307.
# Adding exchange reaction EX_e_0308 with default bounds for boundary metabolite: e_0308.
# Adding exchange reaction EX_e_0309 with default bounds for boundary metabolite: e_0309.
# Adding exchange reaction EX_e_0310 with default bounds for boundary metabolite: e_0310.
# Adding exchange reaction EX_e_0311 with default bounds for boundary metabolite: e_0311.
# Adding exchange reaction EX_e_0312 with default bounds for boundary metabolite: e_0312.
# Adding exchange reaction EX_e_0313 with default bounds for boundary metabolite: e_0313.
# Adding exchange reaction EX_e_0314 with default bounds for boundary metabolite: e_0314.
# Adding exchange reaction EX_e_0315 with default bounds for boundary metabolite: e_0315.
# Adding exchange reaction EX_e_0316 with default bounds for boundary metabolite: e_0316.
# Adding exchange reaction EX_e_0317 with default bounds for boundary metabolite: e_0317.
# Adding exchange reaction EX_e_0320 with default bounds for boundary metabolite: e_0320.
# Adding exchange reaction EX_e_0321 with default bounds for boundary metabolite: e_0321.
# Adding exchange reaction EX_e_0322 with default bounds for boundary metabolite: e_0322.
# Adding exchange reaction EX_e_0323 with default bounds for boundary metabolite: e_0323.
# Adding exchange reaction EX_e_0324 with default bounds for boundary metabolite: e_0324.
# Adding exchange reaction EX_e_0325 with default bounds for boundary metabolite: e_0325.
# Adding exchange reaction EX_e_0326 with default bounds for boundary metabolite: e_0326.
# Adding exchange reaction EX_e_0327 with default bounds for boundary metabolite: e_0327.
# Adding exchange reaction EX_e_0328 with default bounds for boundary metabolite: e_0328.
# Adding exchange reaction EX_e_0329 with default bounds for boundary metabolite: e_0329.
# Adding exchange reaction EX_e_0330 with default bounds for boundary metabolite: e_0330.
# Adding exchange reaction EX_e_0331 with default bounds for boundary metabolite: e_0331.
# Adding exchange reaction EX_e_0332 with default bounds for boundary metabolite: e_0332.
# Adding exchange reaction EX_e_0334 with default bounds for boundary metabolite: e_0334.
# Adding exchange reaction EX_e_0335 with default bounds for boundary metabolite: e_0335.
# Adding exchange reaction EX_e_0336 with default bounds for boundary metabolite: e_0336.
# Adding exchange reaction EX_e_0337 with default bounds for boundary metabolite: e_0337.
# Adding exchange reaction EX_e_0338 with default bounds for boundary metabolite: e_0338.
# Adding exchange reaction EX_e_0339 with default bounds for boundary metabolite: e_0339.
# Adding exchange reaction EX_e_0340 with default bounds for boundary metabolite: e_0340.
# Adding exchange reaction EX_e_0341 with default bounds for boundary metabolite: e_0341.
# Adding exchange reaction EX_e_0342 with default bounds for boundary metabolite: e_0342.
# Adding exchange reaction EX_e_0343 with default bounds for boundary metabolite: e_0343.
# Adding exchange reaction EX_e_0344 with default bounds for boundary metabolite: e_0344.
# Adding exchange reaction EX_e_0345 with default bounds for boundary metabolite: e_0345.
# Adding exchange reaction EX_e_0346 with default bounds for boundary metabolite: e_0346.
# Adding exchange reaction EX_e_0347 with default bounds for boundary metabolite: e_0347.
# Adding exchange reaction EX_e_0348 with default bounds for boundary metabolite: e_0348.
# Adding exchange reaction EX_e_0349 with default bounds for boundary metabolite: e_0349.
# Adding exchange reaction EX_e_0350 with default bounds for boundary metabolite: e_0350.
# Adding exchange reaction EX_e_0351 with default bounds for boundary metabolite: e_0351.
# Adding exchange reaction EX_e_0352 with default bounds for boundary metabolite: e_0352.
# Adding exchange reaction EX_e_0353 with default bounds for boundary metabolite: e_0353.
# Adding exchange reaction EX_e_0354 with default bounds for boundary metabolite: e_0354.
# Adding exchange reaction EX_e_0355 with default bounds for boundary metabolite: e_0355.
# Adding exchange reaction EX_e_0356 with default bounds for boundary metabolite: e_0356.
# Adding exchange reaction EX_e_0357 with default bounds for boundary metabolite: e_0357.
# Adding exchange reaction EX_e_0358 with default bounds for boundary metabolite: e_0358.
# Adding exchange reaction EX_e_0359 with default bounds for boundary metabolite: e_0359.
# Adding exchange reaction EX_e_0361 with default bounds for boundary metabolite: e_0361.
# Adding exchange reaction EX_e_0362 with default bounds for boundary metabolite: e_0362.
# Adding exchange reaction EX_e_0363 with default bounds for boundary metabolite: e_0363.
# Adding exchange reaction EX_e_0364 with default bounds for boundary metabolite: e_0364.
# Adding exchange reaction EX_e_0366 with default bounds for boundary metabolite: e_0366.
# Adding exchange reaction EX_e_0367 with default bounds for boundary metabolite: e_0367.
# Adding exchange reaction EX_e_0368 with default bounds for boundary metabolite: e_0368.
# Adding exchange reaction EX_e_0369 with default bounds for boundary metabolite: e_0369.
# Adding exchange reaction EX_e_0370 with default bounds for boundary metabolite: e_0370.
# Adding exchange reaction EX_e_0371 with default bounds for boundary metabolite: e_0371.
# Adding exchange reaction EX_e_0372 with default bounds for boundary metabolite: e_0372.
# Adding exchange reaction EX_e_0373 with default bounds for boundary metabolite: e_0373.
# Adding exchange reaction EX_e_0374 with default bounds for boundary metabolite: e_0374.
# Adding exchange reaction EX_e_0375 with default bounds for boundary metabolite: e_0375.
# Adding exchange reaction EX_e_0376 with default bounds for boundary metabolite: e_0376.
# Adding exchange reaction EX_e_0377 with default bounds for boundary metabolite: e_0377.
# Adding exchange reaction EX_e_0378 with default bounds for boundary metabolite: e_0378.
# Adding exchange reaction EX_e_0379 with default bounds for boundary metabolite: e_0379.
# Adding exchange reaction EX_e_0380 with default bounds for boundary metabolite: e_0380.
# Adding exchange reaction EX_e_0384 with default bounds for boundary metabolite: e_0384.
# Adding exchange reaction EX_e_0385 with default bounds for boundary metabolite: e_0385.
# Adding exchange reaction EX_e_0386 with default bounds for boundary metabolite: e_0386.
# Adding exchange reaction EX_e_0387 with default bounds for boundary metabolite: e_0387.
# Adding exchange reaction EX_e_0388 with default bounds for boundary metabolite: e_0388.
# Adding exchange reaction EX_e_0389 with default bounds for boundary metabolite: e_0389.
# Adding exchange reaction EX_e_0390 with default bounds for boundary metabolite: e_0390.
# Adding exchange reaction EX_e_0391 with default bounds for boundary metabolite: e_0391.
# Adding exchange reaction EX_e_0392 with default bounds for boundary metabolite: e_0392.
# Adding exchange reaction EX_e_0393 with default bounds for boundary metabolite: e_0393.
# Adding exchange reaction EX_e_0394 with default bounds for boundary metabolite: e_0394.
# Adding exchange reaction EX_e_0395 with default bounds for boundary metabolite: e_0395.
# Adding exchange reaction EX_e_0396 with default bounds for boundary metabolite: e_0396.
# Adding exchange reaction EX_e_0397 with default bounds for boundary metabolite: e_0397.
# Adding exchange reaction EX_e_0398 with default bounds for boundary metabolite: e_0398.
# Adding exchange reaction EX_e_0399 with default bounds for boundary metabolite: e_0399.
# Adding exchange reaction EX_e_0400 with default bounds for boundary metabolite: e_0400.
# Adding exchange reaction EX_e_0401 with default bounds for boundary metabolite: e_0401.
# Adding exchange reaction EX_e_0402 with default bounds for boundary metabolite: e_0402.
# Adding exchange reaction EX_e_0403 with default bounds for boundary metabolite: e_0403.
# Adding exchange reaction EX_e_0404 with default bounds for boundary metabolite: e_0404.
# Adding exchange reaction EX_e_0405 with default bounds for boundary metabolite: e_0405.
# Adding exchange reaction EX_e_0406 with default bounds for boundary metabolite: e_0406.
# Adding exchange reaction EX_e_0407 with default bounds for boundary metabolite: e_0407.
# Adding exchange reaction EX_e_0408 with default bounds for boundary metabolite: e_0408.
# Adding exchange reaction EX_e_0409 with default bounds for boundary metabolite: e_0409.
# Adding exchange reaction EX_e_0410 with default bounds for boundary metabolite: e_0410.
# Adding exchange reaction EX_e_0411 with default bounds for boundary metabolite: e_0411.
# Adding exchange reaction EX_e_0412 with default bounds for boundary metabolite: e_0412.
# Adding exchange reaction EX_e_0413 with default bounds for boundary metabolite: e_0413.
# Adding exchange reaction EX_e_0414 with default bounds for boundary metabolite: e_0414.
# Adding exchange reaction EX_e_0415 with default bounds for boundary metabolite: e_0415.
# Adding exchange reaction EX_e_0416 with default bounds for boundary metabolite: e_0416.
# Adding exchange reaction EX_e_0417 with default bounds for boundary metabolite: e_0417.
# Adding exchange reaction EX_e_0418 with default bounds for boundary metabolite: e_0418.
# Adding exchange reaction EX_e_0419 with default bounds for boundary metabolite: e_0419.
# ...
# Adding exchange reaction EX_e_0875 with default bounds for boundary metabolite: e_0875.
# Adding exchange reaction EX_e_0876 with default bounds for boundary metabolite: e_0876.
# Adding exchange reaction EX_e_0877 with default bounds for boundary metabolite: e_0877.
# Adding exchange reaction EX_e_0878 with default bounds for boundary metabolite: e_0878.
# Adding exchange reaction EX_e_0879 with default bounds for boundary metabolite: e_0879.
# Adding exchange reaction EX_e_0880 with default bounds for boundary metabolite: e_0880.
# Adding exchange reaction EX_e_0881 with default bounds for boundary metabolite: e_0881.
# Adding exchange reaction EX_e_0882 with default bounds for boundary metabolite: e_0882.
# Adding exchange reaction EX_e_0883 with default bounds for boundary metabolite: e_0883.
# Adding exchange reaction EX_e_0884 with default bounds for boundary metabolite: e_0884.
# Adding exchange reaction EX_e_0885 with default bounds for boundary metabolite: e_0885.
# Adding exchange reaction EX_e_0886 with default bounds for boundary metabolite: e_0886.
# Adding exchange reaction EX_e_0887 with default bounds for boundary metabolite: e_0887.
# Adding exchange reaction EX_e_0888 with default bounds for boundary metabolite: e_0888.
# Adding exchange reaction EX_e_0890 with default bounds for boundary metabolite: e_0890.
# Adding exchange reaction EX_e_0891 with default bounds for boundary metabolite: e_0891.
# Adding exchange reaction EX_e_0892 with default bounds for boundary metabolite: e_0892.
# Adding exchange reaction EX_e_0893 with default bounds for boundary metabolite: e_0893.
# Adding exchange reaction EX_e_0894 with default bounds for boundary metabolite: e_0894.
# Adding exchange reaction EX_e_0895 with default bounds for boundary metabolite: e_0895.
# Adding exchange reaction EX_e_0896 with default bounds for boundary metabolite: e_0896.
# Adding exchange reaction EX_e_0897 with default bounds for boundary metabolite: e_0897.
# Adding exchange reaction EX_e_0898 with default bounds for boundary metabolite: e_0898.
# Adding exchange reaction EX_e_0899 with default bounds for boundary metabolite: e_0899.
# Adding exchange reaction EX_e_0900 with default bounds for boundary metabolite: e_0900.
# Adding exchange reaction EX_e_0901 with default bounds for boundary metabolite: e_0901.
# Adding exchange reaction EX_e_0902 with default bounds for boundary metabolite: e_0902.
# Adding exchange reaction EX_e_0903 with default bounds for boundary metabolite: e_0903.
# Adding exchange reaction EX_e_0904 with default bounds for boundary metabolite: e_0904.
# Adding exchange reaction EX_e_0905 with default bounds for boundary metabolite: e_0905.
# Adding exchange reaction EX_e_0906 with default bounds for boundary metabolite: e_0906.
# Adding exchange reaction EX_e_0907 with default bounds for boundary metabolite: e_0907.
# Adding exchange reaction EX_e_0908 with default bounds for boundary metabolite: e_0908.
# Adding exchange reaction EX_e_0909 with default bounds for boundary metabolite: e_0909.
# Adding exchange reaction EX_e_0910 with default bounds for boundary metabolite: e_0910.
# Adding exchange reaction EX_e_0911 with default bounds for boundary metabolite: e_0911.
# Adding exchange reaction EX_e_0912 with default bounds for boundary metabolite: e_0912.
# Adding exchange reaction EX_e_0913 with default bounds for boundary metabolite: e_0913.
# Adding exchange reaction EX_e_0914 with default bounds for boundary metabolite: e_0914.
# Adding exchange reaction EX_e_0915 with default bounds for boundary metabolite: e_0915.
# Adding exchange reaction EX_e_0916 with default bounds for boundary metabolite: e_0916.
# Adding exchange reaction EX_e_0917 with default bounds for boundary metabolite: e_0917.
# Adding exchange reaction EX_e_0918 with default bounds for boundary metabolite: e_0918.
# Adding exchange reaction EX_e_0919 with default bounds for boundary metabolite: e_0919.
# Adding exchange reaction EX_e_0920 with default bounds for boundary metabolite: e_0920.
# Adding exchange reaction EX_e_0921 with default bounds for boundary metabolite: e_0921.
# Adding exchange reaction EX_e_0922 with default bounds for boundary metabolite: e_0922.
# Adding exchange reaction EX_e_0923 with default bounds for boundary metabolite: e_0923.
# Adding exchange reaction EX_e_0924 with default bounds for boundary metabolite: e_0924.
# Adding exchange reaction EX_e_0925 with default bounds for boundary metabolite: e_0925.
# Adding exchange reaction EX_e_0926 with default bounds for boundary metabolite: e_0926.
# Adding exchange reaction EX_e_0927 with default bounds for boundary metabolite: e_0927.
# Adding exchange reaction EX_e_0928 with default bounds for boundary metabolite: e_0928.
# Adding exchange reaction EX_e_0929 with default bounds for boundary metabolite: e_0929.
# Adding exchange reaction EX_e_0932 with default bounds for boundary metabolite: e_0932.
# Adding exchange reaction EX_e_0933 with default bounds for boundary metabolite: e_0933.
# Adding exchange reaction EX_e_0934 with default bounds for boundary metabolite: e_0934.
# Adding exchange reaction EX_e_0935 with default bounds for boundary metabolite: e_0935.
# Adding exchange reaction EX_e_0936 with default bounds for boundary metabolite: e_0936.
# Adding exchange reaction EX_e_0937 with default bounds for boundary metabolite: e_0937.
# Adding exchange reaction EX_e_0938 with default bounds for boundary metabolite: e_0938.
# Adding exchange reaction EX_e_0939 with default bounds for boundary metabolite: e_0939.
# Adding exchange reaction EX_e_0940 with default bounds for boundary metabolite: e_0940.
# Adding exchange reaction EX_e_0941 with default bounds for boundary metabolite: e_0941.
# Adding exchange reaction EX_e_0942 with default bounds for boundary metabolite: e_0942.
# Adding exchange reaction EX_e_0943 with default bounds for boundary metabolite: e_0943.
# Adding exchange reaction EX_e_0944 with default bounds for boundary metabolite: e_0944.
# Adding exchange reaction EX_e_0945 with default bounds for boundary metabolite: e_0945.
# Adding exchange reaction EX_e_0946 with default bounds for boundary metabolite: e_0946.
# Adding exchange reaction EX_e_0947 with default bounds for boundary metabolite: e_0947.
# Adding exchange reaction EX_e_0948 with default bounds for boundary metabolite: e_0948.
# Adding exchange reaction EX_e_0949 with default bounds for boundary metabolite: e_0949.
# Adding exchange reaction EX_e_0950 with default bounds for boundary metabolite: e_0950.
# Adding exchange reaction EX_e_0951 with default bounds for boundary metabolite: e_0951.
# Adding exchange reaction EX_e_0952 with default bounds for boundary metabolite: e_0952.
# Adding exchange reaction EX_e_0953 with default bounds for boundary metabolite: e_0953.
# Adding exchange reaction EX_e_0954 with default bounds for boundary metabolite: e_0954.
# Adding exchange reaction EX_e_0955 with default bounds for boundary metabolite: e_0955.
# Adding exchange reaction EX_e_0956 with default bounds for boundary metabolite: e_0956.
# Adding exchange reaction EX_e_0957 with default bounds for boundary metabolite: e_0957.
# Adding exchange reaction EX_e_0958 with default bounds for boundary metabolite: e_0958.
# Adding exchange reaction EX_e_0959 with default bounds for boundary metabolite: e_0959.
# Adding exchange reaction EX_e_0960 with default bounds for boundary metabolite: e_0960.
# Adding exchange reaction EX_e_0961 with default bounds for boundary metabolite: e_0961.
# Adding exchange reaction EX_e_0962 with default bounds for boundary metabolite: e_0962.
# Adding exchange reaction EX_e_0963 with default bounds for boundary metabolite: e_0963.
# Adding exchange reaction EX_e_0966 with default bounds for boundary metabolite: e_0966.
# Adding exchange reaction EX_e_0967 with default bounds for boundary metabolite: e_0967.
# Adding exchange reaction EX_e_0968 with default bounds for boundary metabolite: e_0968.
# Adding exchange reaction EX_e_0970 with default bounds for boundary metabolite: e_0970.
# Adding exchange reaction EX_e_0971 with default bounds for boundary metabolite: e_0971.
# Adding exchange reaction EX_e_0972 with default bounds for boundary metabolite: e_0972.
# Adding exchange reaction EX_e_0973 with default bounds for boundary metabolite: e_0973.
# Adding exchange reaction EX_e_0974 with default bounds for boundary metabolite: e_0974.
# Adding exchange reaction EX_e_0975 with default bounds for boundary metabolite: e_0975.
# Adding exchange reaction EX_e_0976 with default bounds for boundary metabolite: e_0976.
# Adding exchange reaction EX_e_0977 with default bounds for boundary metabolite: e_0977.
# Adding exchange reaction EX_e_0978 with default bounds for boundary metabolite: e_0978.
# Adding exchange reaction EX_e_0979 with default bounds for boundary metabolite: e_0979.
# Adding exchange reaction EX_e_0980 with default bounds for boundary metabolite: e_0980.
# Adding exchange reaction EX_e_0981 with default bounds for boundary metabolite: e_0981.
# Adding exchange reaction EX_e_0982 with default bounds for boundary metabolite: e_0982.
# Adding exchange reaction EX_e_0983 with default bounds for boundary metabolite: e_0983.
# Adding exchange reaction EX_s_2765 with default bounds for boundary metabolite: s_2765.
# Adding exchange reaction EX_s_2767 with default bounds for boundary metabolite: s_2767.
# Adding exchange reaction EX_e_0984 with default bounds for boundary metabolite: e_0984.
# Adding exchange reaction EX_e_0985 with default bounds for boundary metabolite: e_0985.
# Adding exchange reaction EX_e_0986 with default bounds for boundary metabolite: e_0986.
# Adding exchange reaction EX_e_0987 with default bounds for boundary metabolite: e_0987.
# Adding exchange reaction EX_e_0988 with default bounds for boundary metabolite: e_0988.
# Adding exchange reaction EX_e_0989 with default bounds for boundary metabolite: e_0989.
# Adding exchange reaction EX_e_0990 with default bounds for boundary metabolite: e_0990.
# Adding exchange reaction EX_e_0991 with default bounds for boundary metabolite: e_0991.
# Adding exchange reaction EX_e_0992 with default bounds for boundary metabolite: e_0992.
# Adding exchange reaction EX_s_2823 with default bounds for boundary metabolite: s_2823.
# Adding exchange reaction EX_s_2825 with default bounds for boundary metabolite: s_2825.
# Adding exchange reaction EX_s_2827 with default bounds for boundary metabolite: s_2827.
# Adding exchange reaction EX_s_2830 with default bounds for boundary metabolite: s_2830.
# Adding exchange reaction EX_e_0993 with default bounds for boundary metabolite: e_0993.
# Adding exchange reaction EX_e_0994 with default bounds for boundary metabolite: e_0994.
# Adding exchange reaction EX_e_0995 with default bounds for boundary metabolite: e_0995.
# Adding exchange reaction EX_e_0996 with default bounds for boundary metabolite: e_0996.
# Adding exchange reaction EX_e_0997 with default bounds for boundary metabolite: e_0997.
# Adding exchange reaction EX_e_0998 with default bounds for boundary metabolite: e_0998.
# Adding exchange reaction EX_e_0999 with default bounds for boundary metabolite: e_0999.
# Adding exchange reaction EX_e_1000 with default bounds for boundary metabolite: e_1000.
# Adding exchange reaction EX_e_1001 with default bounds for boundary metabolite: e_1001.
# Adding exchange reaction EX_e_1002 with default bounds for boundary metabolite: e_1002.
# Adding exchange reaction EX_e_1003 with default bounds for boundary metabolite: e_1003.
# Adding exchange reaction EX_e_1004 with default bounds for boundary metabolite: e_1004.
# Adding exchange reaction EX_e_1005 with default bounds for boundary metabolite: e_1005.
# Adding exchange reaction EX_e_1006 with default bounds for boundary metabolite: e_1006.
# Adding exchange reaction EX_e_1007 with default bounds for boundary metabolite: e_1007.
# Adding exchange reaction EX_e_1008 with default bounds for boundary metabolite: e_1008.
# Adding exchange reaction EX_e_1009 with default bounds for boundary metabolite: e_1009.
# Adding exchange reaction EX_e_1010 with default bounds for boundary metabolite: e_1010.
# Adding exchange reaction EX_e_1011 with default bounds for boundary metabolite: e_1011.
# Adding exchange reaction EX_e_1012 with default bounds for boundary metabolite: e_1012.
# Adding exchange reaction EX_e_1013 with default bounds for boundary metabolite: e_1013.
# Adding exchange reaction EX_e_1014 with default bounds for boundary metabolite: e_1014.
# Adding exchange reaction EX_e_1015 with default bounds for boundary metabolite: e_1015.
# Adding exchange reaction EX_e_1016 with default bounds for boundary metabolite: e_1016.
# Adding exchange reaction EX_e_1017 with default bounds for boundary metabolite: e_1017.
# Adding exchange reaction EX_e_1018 with default bounds for boundary metabolite: e_1018.
# Adding exchange reaction EX_e_1019 with default bounds for boundary metabolite: e_1019.
# Adding exchange reaction EX_e_1020 with default bounds for boundary metabolite: e_1020.
# Adding exchange reaction EX_e_1021 with default bounds for boundary metabolite: e_1021.
# Adding exchange reaction EX_e_1022 with default bounds for boundary metabolite: e_1022.
# Adding exchange reaction EX_e_1023 with default bounds for boundary metabolite: e_1023.
# Adding exchange reaction EX_e_1024 with default bounds for boundary metabolite: e_1024.
# Adding exchange reaction EX_e_1025 with default bounds for boundary metabolite: e_1025.
# Adding exchange reaction EX_e_1026 with default bounds for boundary metabolite: e_1026.
# Adding exchange reaction EX_e_1027 with default bounds for boundary metabolite: e_1027.
# Adding exchange reaction EX_e_1028 with default bounds for boundary metabolite: e_1028.
# Adding exchange reaction EX_e_1029 with default bounds for boundary metabolite: e_1029.
# Adding exchange reaction EX_e_1030 with default bounds for boundary metabolite: e_1030.
# Adding exchange reaction EX_e_1031 with default bounds for boundary metabolite: e_1031.
# Adding exchange reaction EX_e_1032 with default bounds for boundary metabolite: e_1032.
# Adding exchange reaction EX_e_1033 with default bounds for boundary metabolite: e_1033.
# Adding exchange reaction EX_e_1034 with default bounds for boundary metabolite: e_1034.
# Adding exchange reaction EX_e_1035 with default bounds for boundary metabolite: e_1035.
# Adding exchange reaction EX_e_1036 with default bounds for boundary metabolite: e_1036.
# Adding exchange reaction EX_e_1037 with default bounds for boundary metabolite: e_1037.
# Adding exchange reaction EX_e_1038 with default bounds for boundary metabolite: e_1038.
# Adding exchange reaction EX_e_1039 with default bounds for boundary metabolite: e_1039.
# Adding exchange reaction EX_e_1040 with default bounds for boundary metabolite: e_1040.
# Adding exchange reaction EX_e_1041 with default bounds for boundary metabolite: e_1041.
# Adding exchange reaction EX_e_1042 with default bounds for boundary metabolite: e_1042.
# Adding exchange reaction EX_e_1043 with default bounds for boundary metabolite: e_1043.
# Adding exchange reaction EX_e_1044 with default bounds for boundary metabolite: e_1044.
# Adding exchange reaction EX_e_1045 with default bounds for boundary metabolite: e_1045.
# Adding exchange reaction EX_e_1046 with default bounds for boundary metabolite: e_1046.
# Adding exchange reaction EX_e_1047 with default bounds for boundary metabolite: e_1047.
# Adding exchange reaction EX_e_1048 with default bounds for boundary metabolite: e_1048.
# Adding exchange reaction EX_e_1049 with default bounds for boundary metabolite: e_1049.
# Adding exchange reaction EX_e_1050 with default bounds for boundary metabolite: e_1050.
# Adding exchange reaction EX_e_1051 with default bounds for boundary metabolite: e_1051.
# Adding exchange reaction EX_s_1796 with default bounds for boundary metabolite: s_1796.
# Adding exchange reaction EX_s_3717 with default bounds for boundary metabolite: s_3717.
# Adding exchange reaction EX_s_3718 with default bounds for boundary metabolite: s_3718.
# Adding exchange reaction EX_e_1053 with default bounds for boundary metabolite: e_1053.
# <Model ymn at 0x103b99b80>

# %%
model_yeast76.optimize()
# Out:
# <Solution 0.095 at 0x12abe2220>

# %%
# %%time
# !memote report snapshot --skip test_stoichiometric_consistency \
    --skip test_find_metabolites_not_produced_with_open_bounds \
    --skip test_find_metabolites_not_consumed_with_open_bounds yeast_7.6/yeast_7.6.xml --filename yeast_7.6.html
# Out:
# warning: Loading SBML model without fbc:strict="true"
# warning: Loading SBML with fbc-v1 (models should be encoded using fbc-v2)
# warning: Adding exchange reaction EX_s_1656 with default bounds for boundary metabolite: s_1656.
# warning: Adding exchange reaction EX_s_1657 with default bounds for boundary metabolite: s_1657.
# warning: Adding exchange reaction EX_s_1658 with default bounds for boundary metabolite: s_1658.
# warning: Adding exchange reaction EX_s_1659 with default bounds for boundary metabolite: s_1659.
# warning: Adding exchange reaction EX_s_1660 with default bounds for boundary metabolite: s_1660.
# warning: Adding exchange reaction EX_s_1661 with default bounds for boundary metabolite: s_1661.
# warning: Adding exchange reaction EX_s_1662 with default bounds for boundary metabolite: s_1662.
# warning: Adding exchange reaction EX_s_1663 with default bounds for boundary metabolite: s_1663.
# warning: Adding exchange reaction EX_s_1664 with default bounds for boundary metabolite: s_1664.
# warning: Adding exchange reaction EX_s_1665 with default bounds for boundary metabolite: s_1665.
# warning: Adding exchange reaction EX_s_1666 with default bounds for boundary metabolite: s_1666.
# warning: Adding exchange reaction EX_s_1667 with default bounds for boundary metabolite: s_1667.
# warning: Adding exchange reaction EX_s_1668 with default bounds for boundary metabolite: s_1668.
# warning: Adding exchange reaction EX_s_1669 with default bounds for boundary metabolite: s_1669.
# warning: Adding exchange reaction EX_s_1670 with default bounds for boundary metabolite: s_1670.
# warning: Adding exchange reaction EX_s_1672 with default bounds for boundary metabolite: s_1672.
# warning: Adding exchange reaction EX_s_1673 with default bounds for boundary metabolite: s_1673.
# warning: Adding exchange reaction EX_s_1674 with default bounds for boundary metabolite: s_1674.
# warning: Adding exchange reaction EX_s_1675 with default bounds for boundary metabolite: s_1675.
# warning: Adding exchange reaction EX_s_1676 with default bounds for boundary metabolite: s_1676.
# warning: Adding exchange reaction EX_s_1677 with default bounds for boundary metabolite: s_1677.
# warning: Adding exchange reaction EX_s_1678 with default bounds for boundary metabolite: s_1678.
# warning: Adding exchange reaction EX_s_1679 with default bounds for boundary metabolite: s_1679.
# warning: Adding exchange reaction EX_s_1680 with default bounds for boundary metabolite: s_1680.
# warning: Adding exchange reaction EX_s_1681 with default bounds for boundary metabolite: s_1681.
# warning: Adding exchange reaction EX_s_1682 with default bounds for boundary metabolite: s_1682.
# warning: Adding exchange reaction EX_s_1683 with default bounds for boundary metabolite: s_1683.
# warning: Adding exchange reaction EX_s_1684 with default bounds for boundary metabolite: s_1684.
# warning: Adding exchange reaction EX_s_1685 with default bounds for boundary metabolite: s_1685.
# warning: Adding exchange reaction EX_s_1686 with default bounds for boundary metabolite: s_1686.
# warning: Adding exchange reaction EX_s_1687 with default bounds for boundary metabolite: s_1687.
# warning: Adding exchange reaction EX_s_1688 with default bounds for boundary metabolite: s_1688.
# warning: Adding exchange reaction EX_s_1689 with default bounds for boundary metabolite: s_1689.
# warning: Adding exchange reaction EX_s_1690 with default bounds for boundary metabolite: s_1690.
# warning: Adding exchange reaction EX_s_1691 with default bounds for boundary metabolite: s_1691.
# warning: Adding exchange reaction EX_s_1692 with default bounds for boundary metabolite: s_1692.
# warning: Adding exchange reaction EX_s_1693 with default bounds for boundary metabolite: s_1693.
# warning: Adding exchange reaction EX_s_1694 with default bounds for boundary metabolite: s_1694.
# warning: Adding exchange reaction EX_s_1695 with default bounds for boundary metabolite: s_1695.
# warning: Adding exchange reaction EX_s_1696 with default bounds for boundary metabolite: s_1696.
# warning: Adding exchange reaction EX_s_1697 with default bounds for boundary metabolite: s_1697.
# warning: Adding exchange reaction EX_s_1698 with default bounds for boundary metabolite: s_1698.
# warning: Adding exchange reaction EX_s_1699 with default bounds for boundary metabolite: s_1699.
# warning: Adding exchange reaction EX_s_1700 with default bounds for boundary metabolite: s_1700.
# warning: Adding exchange reaction EX_s_1701 with default bounds for boundary metabolite: s_1701.
# warning: Adding exchange reaction EX_s_1702 with default bounds for boundary metabolite: s_1702.
# warning: Adding exchange reaction EX_s_1703 with default bounds for boundary metabolite: s_1703.
# warning: Adding exchange reaction EX_s_1704 with default bounds for boundary metabolite: s_1704.
# warning: Adding exchange reaction EX_s_1705 with default bounds for boundary metabolite: s_1705.
# warning: Adding exchange reaction EX_s_1706 with default bounds for boundary metabolite: s_1706.
# warning: Adding exchange reaction EX_s_1707 with default bounds for boundary metabolite: s_1707.
# warning: Adding exchange reaction EX_s_1708 with default bounds for boundary metabolite: s_1708.
# warning: Adding exchange reaction EX_s_1709 with default bounds for boundary metabolite: s_1709.
# warning: Adding exchange reaction EX_s_1710 with default bounds for boundary metabolite: s_1710.
# warning: Adding exchange reaction EX_s_1711 with default bounds for boundary metabolite: s_1711.
# warning: Adding exchange reaction EX_s_1712 with default bounds for boundary metabolite: s_1712.
# warning: Adding exchange reaction EX_s_1713 with default bounds for boundary metabolite: s_1713.
# warning: Adding exchange reaction EX_s_1714 with default bounds for boundary metabolite: s_1714.
# warning: Adding exchange reaction EX_s_1715 with default bounds for boundary metabolite: s_1715.
# warning: Adding exchange reaction EX_s_1716 with default bounds for boundary metabolite: s_1716.
# warning: Adding exchange reaction EX_s_1717 with default bounds for boundary metabolite: s_1717.
# warning: Adding exchange reaction EX_s_1719 with default bounds for boundary metabolite: s_1719.
# warning: Adding exchange reaction EX_s_1720 with default bounds for boundary metabolite: s_1720.
# warning: Adding exchange reaction EX_s_1721 with default bounds for boundary metabolite: s_1721.
# warning: Adding exchange reaction EX_s_1722 with default bounds for boundary metabolite: s_1722.
# warning: Adding exchange reaction EX_s_1723 with default bounds for boundary metabolite: s_1723.
# warning: Adding exchange reaction EX_s_1725 with default bounds for boundary metabolite: s_1725.
# warning: Adding exchange reaction EX_s_1726 with default bounds for boundary metabolite: s_1726.
# warning: Adding exchange reaction EX_s_1727 with default bounds for boundary metabolite: s_1727.
# warning: Adding exchange reaction EX_s_1728 with default bounds for boundary metabolite: s_1728.
# warning: Adding exchange reaction EX_s_1729 with default bounds for boundary metabolite: s_1729.
# warning: Adding exchange reaction EX_s_1730 with default bounds for boundary metabolite: s_1730.
# warning: Adding exchange reaction EX_s_1731 with default bounds for boundary metabolite: s_1731.
# warning: Adding exchange reaction EX_s_1732 with default bounds for boundary metabolite: s_1732.
# warning: Adding exchange reaction EX_s_1733 with default bounds for boundary metabolite: s_1733.
# warning: Adding exchange reaction EX_s_1734 with default bounds for boundary metabolite: s_1734.
# warning: Adding exchange reaction EX_s_1735 with default bounds for boundary metabolite: s_1735.
# warning: Adding exchange reaction EX_s_1736 with default bounds for boundary metabolite: s_1736.
# warning: Adding exchange reaction EX_s_1737 with default bounds for boundary metabolite: s_1737.
# warning: Adding exchange reaction EX_s_1738 with default bounds for boundary metabolite: s_1738.
# warning: Adding exchange reaction EX_s_1739 with default bounds for boundary metabolite: s_1739.
# warning: Adding exchange reaction EX_s_1740 with default bounds for boundary metabolite: s_1740.
# warning: Adding exchange reaction EX_s_1741 with default bounds for boundary metabolite: s_1741.
# warning: Adding exchange reaction EX_s_1742 with default bounds for boundary metabolite: s_1742.
# warning: Adding exchange reaction EX_s_1743 with default bounds for boundary metabolite: s_1743.
# warning: Adding exchange reaction EX_s_1744 with default bounds for boundary metabolite: s_1744.
# warning: Adding exchange reaction EX_s_1745 with default bounds for boundary metabolite: s_1745.
# warning: Adding exchange reaction EX_s_1746 with default bounds for boundary metabolite: s_1746.
# warning: Adding exchange reaction EX_s_1747 with default bounds for boundary metabolite: s_1747.
# warning: Adding exchange reaction EX_s_1748 with default bounds for boundary metabolite: s_1748.
# warning: Adding exchange reaction EX_s_1749 with default bounds for boundary metabolite: s_1749.
# warning: Adding exchange reaction EX_s_1750 with default bounds for boundary metabolite: s_1750.
# warning: Adding exchange reaction EX_s_1751 with default bounds for boundary metabolite: s_1751.
# warning: Adding exchange reaction EX_s_1752 with default bounds for boundary metabolite: s_1752.
# warning: Adding exchange reaction EX_s_1753 with default bounds for boundary metabolite: s_1753.
# warning: Adding exchange reaction EX_s_1754 with default bounds for boundary metabolite: s_1754.
# warning: Adding exchange reaction EX_s_1755 with default bounds for boundary metabolite: s_1755.
# warning: Adding exchange reaction EX_s_1756 with default bounds for boundary metabolite: s_1756.
# warning: Adding exchange reaction EX_s_1757 with default bounds for boundary metabolite: s_1757.
# warning: Adding exchange reaction EX_s_1758 with default bounds for boundary metabolite: s_1758.
# warning: Adding exchange reaction EX_s_1759 with default bounds for boundary metabolite: s_1759.
# warning: Adding exchange reaction EX_s_1760 with default bounds for boundary metabolite: s_1760.
# warning: Adding exchange reaction EX_s_1761 with default bounds for boundary metabolite: s_1761.
# warning: Adding exchange reaction EX_s_1762 with default bounds for boundary metabolite: s_1762.
# warning: Adding exchange reaction EX_s_1763 with default bounds for boundary metabolite: s_1763.
# warning: Adding exchange reaction EX_s_1764 with default bounds for boundary metabolite: s_1764.
# warning: Adding exchange reaction EX_s_1765 with default bounds for boundary metabolite: s_1765.
# warning: Adding exchange reaction EX_s_1766 with default bounds for boundary metabolite: s_1766.
# warning: Adding exchange reaction EX_s_1767 with default bounds for boundary metabolite: s_1767.
# warning: Adding exchange reaction EX_s_1768 with default bounds for boundary metabolite: s_1768.
# warning: Adding exchange reaction EX_s_1769 with default bounds for boundary metabolite: s_1769.
# warning: Adding exchange reaction EX_s_1770 with default bounds for boundary metabolite: s_1770.
# warning: Adding exchange reaction EX_s_1771 with default bounds for boundary metabolite: s_1771.
# warning: Adding exchange reaction EX_s_1774 with default bounds for boundary metabolite: s_1774.
# warning: Adding exchange reaction EX_s_1776 with default bounds for boundary metabolite: s_1776.
# warning: Adding exchange reaction EX_s_1779 with default bounds for boundary metabolite: s_1779.
# warning: Adding exchange reaction EX_s_1781 with default bounds for boundary metabolite: s_1781.
# warning: Adding exchange reaction EX_s_1782 with default bounds for boundary metabolite: s_1782.
# warning: Adding exchange reaction EX_s_1783 with default bounds for boundary metabolite: s_1783.
# warning: Adding exchange reaction EX_s_1785 with default bounds for boundary metabolite: s_1785.
# warning: Adding exchange reaction EX_s_1786 with default bounds for boundary metabolite: s_1786.
# warning: Adding exchange reaction EX_s_1787 with default bounds for boundary metabolite: s_1787.
# warning: Adding exchange reaction EX_s_1788 with default bounds for boundary metabolite: s_1788.
# warning: Adding exchange reaction EX_s_1789 with default bounds for boundary metabolite: s_1789.
# warning: Adding exchange reaction EX_s_1790 with default bounds for boundary metabolite: s_1790.
# warning: Adding exchange reaction EX_s_1791 with default bounds for boundary metabolite: s_1791.
# warning: Adding exchange reaction EX_s_1792 with default bounds for boundary metabolite: s_1792.
# warning: Adding exchange reaction EX_s_1793 with default bounds for boundary metabolite: s_1793.
# warning: Adding exchange reaction EX_s_1797 with default bounds for boundary metabolite: s_1797.
# warning: Adding exchange reaction EX_s_1798 with default bounds for boundary metabolite: s_1798.
# warning: Adding exchange reaction EX_s_1799 with default bounds for boundary metabolite: s_1799.
# warning: Adding exchange reaction EX_s_1800 with default bounds for boundary metabolite: s_1800.
# warning: Adding exchange reaction EX_s_1801 with default bounds for boundary metabolite: s_1801.
# warning: Adding exchange reaction EX_s_1802 with default bounds for boundary metabolite: s_1802.
# warning: Adding exchange reaction EX_s_1803 with default bounds for boundary metabolite: s_1803.
# warning: Adding exchange reaction EX_s_1804 with default bounds for boundary metabolite: s_1804.
# warning: Adding exchange reaction EX_s_1805 with default bounds for boundary metabolite: s_1805.
# warning: Adding exchange reaction EX_s_1806 with default bounds for boundary metabolite: s_1806.
# warning: Adding exchange reaction EX_s_1807 with default bounds for boundary metabolite: s_1807.
# warning: Adding exchange reaction EX_s_1808 with default bounds for boundary metabolite: s_1808.
# warning: Adding exchange reaction EX_s_1809 with default bounds for boundary metabolite: s_1809.
# warning: Adding exchange reaction EX_s_1810 with default bounds for boundary metabolite: s_1810.
# warning: Adding exchange reaction EX_s_1811 with default bounds for boundary metabolite: s_1811.
# warning: Adding exchange reaction EX_s_1812 with default bounds for boundary metabolite: s_1812.
# warning: Adding exchange reaction EX_s_1813 with default bounds for boundary metabolite: s_1813.
# warning: Adding exchange reaction EX_s_1814 with default bounds for boundary metabolite: s_1814.
# warning: Adding exchange reaction EX_s_1815 with default bounds for boundary metabolite: s_1815.
# warning: Adding exchange reaction EX_s_1817 with default bounds for boundary metabolite: s_1817.
# warning: Adding exchange reaction EX_s_1818 with default bounds for boundary metabolite: s_1818.
# warning: Adding exchange reaction EX_s_1819 with default bounds for boundary metabolite: s_1819.
# warning: Adding exchange reaction EX_s_1820 with default bounds for boundary metabolite: s_1820.
# warning: Adding exchange reaction EX_s_1821 with default bounds for boundary metabolite: s_1821.
# warning: Adding exchange reaction EX_s_1822 with default bounds for boundary metabolite: s_1822.
# warning: Adding exchange reaction EX_s_1823 with default bounds for boundary metabolite: s_1823.
# warning: Adding exchange reaction EX_s_1824 with default bounds for boundary metabolite: s_1824.
# warning: Adding exchange reaction EX_s_1825 with default bounds for boundary metabolite: s_1825.
# warning: Adding exchange reaction EX_s_2761 with default bounds for boundary metabolite: s_2761.
# warning: Adding exchange reaction EX_e_0001 with default bounds for boundary metabolite: e_0001.
# warning: Adding exchange reaction EX_e_0002 with default bounds for boundary metabolite: e_0002.
# warning: Adding exchange reaction EX_e_0003 with default bounds for boundary metabolite: e_0003.
# warning: Adding exchange reaction EX_e_0004 with default bounds for boundary metabolite: e_0004.
# warning: Adding exchange reaction EX_e_0005 with default bounds for boundary metabolite: e_0005.
# warning: Adding exchange reaction EX_e_0006 with default bounds for boundary metabolite: e_0006.
# warning: Adding exchange reaction EX_e_0007 with default bounds for boundary metabolite: e_0007.
# warning: Adding exchange reaction EX_e_0008 with default bounds for boundary metabolite: e_0008.
# warning: Adding exchange reaction EX_e_0009 with default bounds for boundary metabolite: e_0009.
# warning: Adding exchange reaction EX_e_0010 with default bounds for boundary metabolite: e_0010.
# warning: Adding exchange reaction EX_e_0011 with default bounds for boundary metabolite: e_0011.
# warning: Adding exchange reaction EX_e_0012 with default bounds for boundary metabolite: e_0012.
# warning: Adding exchange reaction EX_e_0013 with default bounds for boundary metabolite: e_0013.
# warning: Adding exchange reaction EX_e_0014 with default bounds for boundary metabolite: e_0014.
# warning: Adding exchange reaction EX_e_0015 with default bounds for boundary metabolite: e_0015.
# warning: Adding exchange reaction EX_e_0016 with default bounds for boundary metabolite: e_0016.
# warning: Adding exchange reaction EX_e_0017 with default bounds for boundary metabolite: e_0017.
# warning: Adding exchange reaction EX_e_0018 with default bounds for boundary metabolite: e_0018.
# warning: Adding exchange reaction EX_e_0019 with default bounds for boundary metabolite: e_0019.
# warning: Adding exchange reaction EX_e_0021 with default bounds for boundary metabolite: e_0021.
# warning: Adding exchange reaction EX_e_0023 with default bounds for boundary metabolite: e_0023.
# warning: Adding exchange reaction EX_e_0024 with default bounds for boundary metabolite: e_0024.
# warning: Adding exchange reaction EX_e_0025 with default bounds for boundary metabolite: e_0025.
# warning: Adding exchange reaction EX_e_0026 with default bounds for boundary metabolite: e_0026.
# warning: Adding exchange reaction EX_e_0027 with default bounds for boundary metabolite: e_0027.
# warning: Adding exchange reaction EX_e_0028 with default bounds for boundary metabolite: e_0028.
# warning: Adding exchange reaction EX_e_0029 with default bounds for boundary metabolite: e_0029.
# warning: Adding exchange reaction EX_e_0030 with default bounds for boundary metabolite: e_0030.
# warning: Adding exchange reaction EX_e_0031 with default bounds for boundary metabolite: e_0031.
# warning: Adding exchange reaction EX_e_0032 with default bounds for boundary metabolite: e_0032.
# warning: Adding exchange reaction EX_e_0033 with default bounds for boundary metabolite: e_0033.
# warning: Adding exchange reaction EX_e_0034 with default bounds for boundary metabolite: e_0034.
# warning: Adding exchange reaction EX_e_0035 with default bounds for boundary metabolite: e_0035.
# warning: Adding exchange reaction EX_e_0036 with default bounds for boundary metabolite: e_0036.
# warning: Adding exchange reaction EX_e_0037 with default bounds for boundary metabolite: e_0037.
# warning: Adding exchange reaction EX_e_0038 with default bounds for boundary metabolite: e_0038.
# warning: Adding exchange reaction EX_e_0039 with default bounds for boundary metabolite: e_0039.
# warning: Adding exchange reaction EX_e_0040 with default bounds for boundary metabolite: e_0040.
# warning: Adding exchange reaction EX_e_0041 with default bounds for boundary metabolite: e_0041.
# warning: Adding exchange reaction EX_e_0042 with default bounds for boundary metabolite: e_0042.
# warning: Adding exchange reaction EX_e_0043 with default bounds for boundary metabolite: e_0043.
# warning: Adding exchange reaction EX_e_0044 with default bounds for boundary metabolite: e_0044.
# warning: Adding exchange reaction EX_e_0047 with default bounds for boundary metabolite: e_0047.
# warning: Adding exchange reaction EX_e_0048 with default bounds for boundary metabolite: e_0048.
# warning: Adding exchange reaction EX_e_0049 with default bounds for boundary metabolite: e_0049.
# warning: Adding exchange reaction EX_e_0050 with default bounds for boundary metabolite: e_0050.
# warning: Adding exchange reaction EX_e_0051 with default bounds for boundary metabolite: e_0051.
# warning: Adding exchange reaction EX_e_0054 with default bounds for boundary metabolite: e_0054.
# warning: Adding exchange reaction EX_e_0055 with default bounds for boundary metabolite: e_0055.
# warning: Adding exchange reaction EX_e_0056 with default bounds for boundary metabolite: e_0056.
# warning: Adding exchange reaction EX_e_0057 with default bounds for boundary metabolite: e_0057.
# warning: Adding exchange reaction EX_e_0058 with default bounds for boundary metabolite: e_0058.
# warning: Adding exchange reaction EX_e_0059 with default bounds for boundary metabolite: e_0059.
# warning: Adding exchange reaction EX_e_0060 with default bounds for boundary metabolite: e_0060.
# warning: Adding exchange reaction EX_e_0061 with default bounds for boundary metabolite: e_0061.
# warning: Adding exchange reaction EX_e_0062 with default bounds for boundary metabolite: e_0062.
# warning: Adding exchange reaction EX_e_0063 with default bounds for boundary metabolite: e_0063.
# warning: Adding exchange reaction EX_e_0064 with default bounds for boundary metabolite: e_0064.
# warning: Adding exchange reaction EX_e_0065 with default bounds for boundary metabolite: e_0065.
# warning: Adding exchange reaction EX_e_0066 with default bounds for boundary metabolite: e_0066.
# warning: Adding exchange reaction EX_e_0067 with default bounds for boundary metabolite: e_0067.
# warning: Adding exchange reaction EX_e_0068 with default bounds for boundary metabolite: e_0068.
# warning: Adding exchange reaction EX_e_0069 with default bounds for boundary metabolite: e_0069.
# warning: Adding exchange reaction EX_e_0070 with default bounds for boundary metabolite: e_0070.
# warning: Adding exchange reaction EX_e_0071 with default bounds for boundary metabolite: e_0071.
# warning: Adding exchange reaction EX_e_0073 with default bounds for boundary metabolite: e_0073.
# warning: Adding exchange reaction EX_e_0074 with default bounds for boundary metabolite: e_0074.
# warning: Adding exchange reaction EX_e_0075 with default bounds for boundary metabolite: e_0075.
# warning: Adding exchange reaction EX_e_0076 with default bounds for boundary metabolite: e_0076.
# warning: Adding exchange reaction EX_e_0077 with default bounds for boundary metabolite: e_0077.
# warning: Adding exchange reaction EX_e_0078 with default bounds for boundary metabolite: e_0078.
# warning: Adding exchange reaction EX_e_0079 with default bounds for boundary metabolite: e_0079.
# warning: Adding exchange reaction EX_e_0080 with default bounds for boundary metabolite: e_0080.
# warning: Adding exchange reaction EX_e_0081 with default bounds for boundary metabolite: e_0081.
# warning: Adding exchange reaction EX_e_0082 with default bounds for boundary metabolite: e_0082.
# warning: Adding exchange reaction EX_e_0083 with default bounds for boundary metabolite: e_0083.
# warning: Adding exchange reaction EX_e_0084 with default bounds for boundary metabolite: e_0084.
# warning: Adding exchange reaction EX_e_0085 with default bounds for boundary metabolite: e_0085.
# warning: Adding exchange reaction EX_e_0086 with default bounds for boundary metabolite: e_0086.
# warning: Adding exchange reaction EX_e_0087 with default bounds for boundary metabolite: e_0087.
# warning: Adding exchange reaction EX_e_0088 with default bounds for boundary metabolite: e_0088.
# warning: Adding exchange reaction EX_e_0089 with default bounds for boundary metabolite: e_0089.
# warning: Adding exchange reaction EX_e_0090 with default bounds for boundary metabolite: e_0090.
# warning: Adding exchange reaction EX_e_0091 with default bounds for boundary metabolite: e_0091.
# warning: Adding exchange reaction EX_e_0092 with default bounds for boundary metabolite: e_0092.
# warning: Adding exchange reaction EX_e_0093 with default bounds for boundary metabolite: e_0093.
# warning: Adding exchange reaction EX_e_0094 with default bounds for boundary metabolite: e_0094.
# warning: Adding exchange reaction EX_e_0095 with default bounds for boundary metabolite: e_0095.
# warning: Adding exchange reaction EX_e_0096 with default bounds for boundary metabolite: e_0096.
# warning: Adding exchange reaction EX_e_0097 with default bounds for boundary metabolite: e_0097.
# warning: Adding exchange reaction EX_e_0098 with default bounds for boundary metabolite: e_0098.
# warning: Adding exchange reaction EX_e_0100 with default bounds for boundary metabolite: e_0100.
# warning: Adding exchange reaction EX_e_0101 with default bounds for boundary metabolite: e_0101.
# warning: Adding exchange reaction EX_e_0102 with default bounds for boundary metabolite: e_0102.
# warning: Adding exchange reaction EX_e_0103 with default bounds for boundary metabolite: e_0103.
# warning: Adding exchange reaction EX_e_0104 with default bounds for boundary metabolite: e_0104.
# warning: Adding exchange reaction EX_e_0105 with default bounds for boundary metabolite: e_0105.
# warning: Adding exchange reaction EX_e_0106 with default bounds for boundary metabolite: e_0106.
# warning: Adding exchange reaction EX_e_0107 with default bounds for boundary metabolite: e_0107.
# warning: Adding exchange reaction EX_e_0108 with default bounds for boundary metabolite: e_0108.
# warning: Adding exchange reaction EX_e_0109 with default bounds for boundary metabolite: e_0109.
# warning: Adding exchange reaction EX_e_0110 with default bounds for boundary metabolite: e_0110.
# warning: Adding exchange reaction EX_e_0111 with default bounds for boundary metabolite: e_0111.
# warning: Adding exchange reaction EX_e_0112 with default bounds for boundary metabolite: e_0112.
# warning: Adding exchange reaction EX_e_0113 with default bounds for boundary metabolite: e_0113.
# warning: Adding exchange reaction EX_e_0114 with default bounds for boundary metabolite: e_0114.
# warning: Adding exchange reaction EX_e_0115 with default bounds for boundary metabolite: e_0115.
# warning: Adding exchange reaction EX_e_0116 with default bounds for boundary metabolite: e_0116.
# warning: Adding exchange reaction EX_e_0119 with default bounds for boundary metabolite: e_0119.
# warning: Adding exchange reaction EX_e_0120 with default bounds for boundary metabolite: e_0120.
# warning: Adding exchange reaction EX_e_0122 with default bounds for boundary metabolite: e_0122.
# warning: Adding exchange reaction EX_e_0123 with default bounds for boundary metabolite: e_0123.
# warning: Adding exchange reaction EX_e_0124 with default bounds for boundary metabolite: e_0124.
# warning: Adding exchange reaction EX_e_0125 with default bounds for boundary metabolite: e_0125.
# warning: Adding exchange reaction EX_e_0126 with default bounds for boundary metabolite: e_0126.
# warning: Adding exchange reaction EX_e_0127 with default bounds for boundary metabolite: e_0127.
# warning: Adding exchange reaction EX_e_0129 with default bounds for boundary metabolite: e_0129.
# warning: Adding exchange reaction EX_e_0130 with default bounds for boundary metabolite: e_0130.
# warning: Adding exchange reaction EX_e_0131 with default bounds for boundary metabolite: e_0131.
# warning: Adding exchange reaction EX_e_0133 with default bounds for boundary metabolite: e_0133.
# warning: Adding exchange reaction EX_e_0134 with default bounds for boundary metabolite: e_0134.
# warning: Adding exchange reaction EX_e_0135 with default bounds for boundary metabolite: e_0135.
# warning: Adding exchange reaction EX_e_0136 with default bounds for boundary metabolite: e_0136.
# warning: Adding exchange reaction EX_e_0137 with default bounds for boundary metabolite: e_0137.
# warning: Adding exchange reaction EX_e_0138 with default bounds for boundary metabolite: e_0138.
# warning: Adding exchange reaction EX_e_0139 with default bounds for boundary metabolite: e_0139.
# warning: Adding exchange reaction EX_e_0140 with default bounds for boundary metabolite: e_0140.
# warning: Adding exchange reaction EX_e_0141 with default bounds for boundary metabolite: e_0141.
# warning: Adding exchange reaction EX_e_0142 with default bounds for boundary metabolite: e_0142.
# warning: Adding exchange reaction EX_e_0143 with default bounds for boundary metabolite: e_0143.
# warning: Adding exchange reaction EX_e_0144 with default bounds for boundary metabolite: e_0144.
# warning: Adding exchange reaction EX_e_0145 with default bounds for boundary metabolite: e_0145.
# warning: Adding exchange reaction EX_e_0146 with default bounds for boundary metabolite: e_0146.
# warning: Adding exchange reaction EX_e_0147 with default bounds for boundary metabolite: e_0147.
# warning: Adding exchange reaction EX_e_0149 with default bounds for boundary metabolite: e_0149.
# warning: Adding exchange reaction EX_e_0150 with default bounds for boundary metabolite: e_0150.
# warning: Adding exchange reaction EX_e_0151 with default bounds for boundary metabolite: e_0151.
# warning: Adding exchange reaction EX_e_0152 with default bounds for boundary metabolite: e_0152.
# warning: Adding exchange reaction EX_e_0153 with default bounds for boundary metabolite: e_0153.
# warning: Adding exchange reaction EX_e_0154 with default bounds for boundary metabolite: e_0154.
# warning: Adding exchange reaction EX_e_0155 with default bounds for boundary metabolite: e_0155.
# warning: Adding exchange reaction EX_e_0156 with default bounds for boundary metabolite: e_0156.
# warning: Adding exchange reaction EX_e_0157 with default bounds for boundary metabolite: e_0157.
# warning: Adding exchange reaction EX_e_0158 with default bounds for boundary metabolite: e_0158.
# warning: Adding exchange reaction EX_e_0159 with default bounds for boundary metabolite: e_0159.
# warning: Adding exchange reaction EX_e_0160 with default bounds for boundary metabolite: e_0160.
# warning: Adding exchange reaction EX_e_0161 with default bounds for boundary metabolite: e_0161.
# warning: Adding exchange reaction EX_e_0162 with default bounds for boundary metabolite: e_0162.
# warning: Adding exchange reaction EX_e_0163 with default bounds for boundary metabolite: e_0163.
# warning: Adding exchange reaction EX_e_0164 with default bounds for boundary metabolite: e_0164.
# warning: Adding exchange reaction EX_e_0165 with default bounds for boundary metabolite: e_0165.
# warning: Adding exchange reaction EX_e_0166 with default bounds for boundary metabolite: e_0166.
# warning: Adding exchange reaction EX_e_0167 with default bounds for boundary metabolite: e_0167.
# warning: Adding exchange reaction EX_e_0168 with default bounds for boundary metabolite: e_0168.
# warning: Adding exchange reaction EX_e_0169 with default bounds for boundary metabolite: e_0169.
# warning: Adding exchange reaction EX_e_0170 with default bounds for boundary metabolite: e_0170.
# warning: Adding exchange reaction EX_e_0171 with default bounds for boundary metabolite: e_0171.
# warning: Adding exchange reaction EX_e_0172 with default bounds for boundary metabolite: e_0172.
# warning: Adding exchange reaction EX_e_0173 with default bounds for boundary metabolite: e_0173.
# warning: Adding exchange reaction EX_e_0174 with default bounds for boundary metabolite: e_0174.
# warning: Adding exchange reaction EX_e_0175 with default bounds for boundary metabolite: e_0175.
# warning: Adding exchange reaction EX_e_0177 with default bounds for boundary metabolite: e_0177.
# warning: Adding exchange reaction EX_e_0179 with default bounds for boundary metabolite: e_0179.
# warning: Adding exchange reaction EX_e_0181 with default bounds for boundary metabolite: e_0181.
# warning: Adding exchange reaction EX_e_0182 with default bounds for boundary metabolite: e_0182.
# warning: Adding exchange reaction EX_e_0183 with default bounds for boundary metabolite: e_0183.
# warning: Adding exchange reaction EX_e_0184 with default bounds for boundary metabolite: e_0184.
# warning: Adding exchange reaction EX_e_0185 with default bounds for boundary metabolite: e_0185.
# warning: Adding exchange reaction EX_e_0186 with default bounds for boundary metabolite: e_0186.
# warning: Adding exchange reaction EX_e_0187 with default bounds for boundary metabolite: e_0187.
# warning: Adding exchange reaction EX_e_0188 with default bounds for boundary metabolite: e_0188.
# warning: Adding exchange reaction EX_e_0189 with default bounds for boundary metabolite: e_0189.
# warning: Adding exchange reaction EX_e_0190 with default bounds for boundary metabolite: e_0190.
# warning: Adding exchange reaction EX_e_0191 with default bounds for boundary metabolite: e_0191.
# warning: Adding exchange reaction EX_e_0192 with default bounds for boundary metabolite: e_0192.
# warning: Adding exchange reaction EX_e_0193 with default bounds for boundary metabolite: e_0193.
# warning: Adding exchange reaction EX_e_0194 with default bounds for boundary metabolite: e_0194.
# warning: Adding exchange reaction EX_e_0195 with default bounds for boundary metabolite: e_0195.
# warning: Adding exchange reaction EX_e_0196 with default bounds for boundary metabolite: e_0196.
# warning: Adding exchange reaction EX_e_0197 with default bounds for boundary metabolite: e_0197.
# warning: Adding exchange reaction EX_e_0198 with default bounds for boundary metabolite: e_0198.
# warning: Adding exchange reaction EX_e_0199 with default bounds for boundary metabolite: e_0199.
# warning: Adding exchange reaction EX_e_0200 with default bounds for boundary metabolite: e_0200.
# warning: Adding exchange reaction EX_e_0201 with default bounds for boundary metabolite: e_0201.
# warning: Adding exchange reaction EX_e_0202 with default bounds for boundary metabolite: e_0202.
# warning: Adding exchange reaction EX_e_0204 with default bounds for boundary metabolite: e_0204.
# warning: Adding exchange reaction EX_e_0205 with default bounds for boundary metabolite: e_0205.
# warning: Adding exchange reaction EX_e_0206 with default bounds for boundary metabolite: e_0206.
# warning: Adding exchange reaction EX_e_0207 with default bounds for boundary metabolite: e_0207.
# warning: Adding exchange reaction EX_e_0208 with default bounds for boundary metabolite: e_0208.
# warning: Adding exchange reaction EX_e_0209 with default bounds for boundary metabolite: e_0209.
# warning: Adding exchange reaction EX_e_0210 with default bounds for boundary metabolite: e_0210.
# warning: Adding exchange reaction EX_e_0211 with default bounds for boundary metabolite: e_0211.
# warning: Adding exchange reaction EX_e_0212 with default bounds for boundary metabolite: e_0212.
# warning: Adding exchange reaction EX_e_0213 with default bounds for boundary metabolite: e_0213.
# warning: Adding exchange reaction EX_e_0214 with default bounds for boundary metabolite: e_0214.
# warning: Adding exchange reaction EX_e_0215 with default bounds for boundary metabolite: e_0215.
# warning: Adding exchange reaction EX_e_0216 with default bounds for boundary metabolite: e_0216.
# warning: Adding exchange reaction EX_e_0217 with default bounds for boundary metabolite: e_0217.
# warning: Adding exchange reaction EX_e_0218 with default bounds for boundary metabolite: e_0218.
# warning: Adding exchange reaction EX_e_0219 with default bounds for boundary metabolite: e_0219.
# warning: Adding exchange reaction EX_e_0221 with default bounds for boundary metabolite: e_0221.
# warning: Adding exchange reaction EX_e_0222 with default bounds for boundary metabolite: e_0222.
# warning: Adding exchange reaction EX_e_0223 with default bounds for boundary metabolite: e_0223.
# warning: Adding exchange reaction EX_e_0224 with default bounds for boundary metabolite: e_0224.
# warning: Adding exchange reaction EX_e_0225 with default bounds for boundary metabolite: e_0225.
# warning: Adding exchange reaction EX_e_0226 with default bounds for boundary metabolite: e_0226.
# warning: Adding exchange reaction EX_e_0227 with default bounds for boundary metabolite: e_0227.
# warning: Adding exchange reaction EX_e_0228 with default bounds for boundary metabolite: e_0228.
# warning: Adding exchange reaction EX_e_0229 with default bounds for boundary metabolite: e_0229.
# warning: Adding exchange reaction EX_e_0230 with default bounds for boundary metabolite: e_0230.
# warning: Adding exchange reaction EX_e_0231 with default bounds for boundary metabolite: e_0231.
# warning: Adding exchange reaction EX_e_0232 with default bounds for boundary metabolite: e_0232.
# warning: Adding exchange reaction EX_e_0233 with default bounds for boundary metabolite: e_0233.
# warning: Adding exchange reaction EX_e_0234 with default bounds for boundary metabolite: e_0234.
# warning: Adding exchange reaction EX_e_0235 with default bounds for boundary metabolite: e_0235.
# warning: Adding exchange reaction EX_e_0236 with default bounds for boundary metabolite: e_0236.
# warning: Adding exchange reaction EX_e_0237 with default bounds for boundary metabolite: e_0237.
# warning: Adding exchange reaction EX_e_0238 with default bounds for boundary metabolite: e_0238.
# warning: Adding exchange reaction EX_e_0239 with default bounds for boundary metabolite: e_0239.
# warning: Adding exchange reaction EX_e_0241 with default bounds for boundary metabolite: e_0241.
# warning: Adding exchange reaction EX_e_0242 with default bounds for boundary metabolite: e_0242.
# warning: Adding exchange reaction EX_e_0243 with default bounds for boundary metabolite: e_0243.
# warning: Adding exchange reaction EX_e_0244 with default bounds for boundary metabolite: e_0244.
# warning: Adding exchange reaction EX_e_0245 with default bounds for boundary metabolite: e_0245.
# warning: Adding exchange reaction EX_e_0246 with default bounds for boundary metabolite: e_0246.
# warning: Adding exchange reaction EX_e_0247 with default bounds for boundary metabolite: e_0247.
# warning: Adding exchange reaction EX_e_0248 with default bounds for boundary metabolite: e_0248.
# warning: Adding exchange reaction EX_e_0249 with default bounds for boundary metabolite: e_0249.
# warning: Adding exchange reaction EX_e_0250 with default bounds for boundary metabolite: e_0250.
# warning: Adding exchange reaction EX_e_0251 with default bounds for boundary metabolite: e_0251.
# warning: Adding exchange reaction EX_e_0252 with default bounds for boundary metabolite: e_0252.
# warning: Adding exchange reaction EX_e_0253 with default bounds for boundary metabolite: e_0253.
# warning: Adding exchange reaction EX_e_0254 with default bounds for boundary metabolite: e_0254.
# warning: Adding exchange reaction EX_e_0255 with default bounds for boundary metabolite: e_0255.
# warning: Adding exchange reaction EX_e_0256 with default bounds for boundary metabolite: e_0256.
# warning: Adding exchange reaction EX_e_0257 with default bounds for boundary metabolite: e_0257.
# warning: Adding exchange reaction EX_e_0258 with default bounds for boundary metabolite: e_0258.
# warning: Adding exchange reaction EX_e_0259 with default bounds for boundary metabolite: e_0259.
# warning: Adding exchange reaction EX_e_0260 with default bounds for boundary metabolite: e_0260.
# warning: Adding exchange reaction EX_e_0261 with default bounds for boundary metabolite: e_0261.
# warning: Adding exchange reaction EX_e_0262 with default bounds for boundary metabolite: e_0262.
# warning: Adding exchange reaction EX_e_0263 with default bounds for boundary metabolite: e_0263.
# warning: Adding exchange reaction EX_e_0264 with default bounds for boundary metabolite: e_0264.
# warning: Adding exchange reaction EX_e_0265 with default bounds for boundary metabolite: e_0265.
# warning: Adding exchange reaction EX_e_0266 with default bounds for boundary metabolite: e_0266.
# warning: Adding exchange reaction EX_e_0267 with default bounds for boundary metabolite: e_0267.
# warning: Adding exchange reaction EX_e_0268 with default bounds for boundary metabolite: e_0268.
# warning: Adding exchange reaction EX_e_0269 with default bounds for boundary metabolite: e_0269.
# warning: Adding exchange reaction EX_e_0270 with default bounds for boundary metabolite: e_0270.
# warning: Adding exchange reaction EX_e_0271 with default bounds for boundary metabolite: e_0271.
# warning: Adding exchange reaction EX_e_0272 with default bounds for boundary metabolite: e_0272.
# warning: Adding exchange reaction EX_e_0273 with default bounds for boundary metabolite: e_0273.
# warning: Adding exchange reaction EX_e_0274 with default bounds for boundary metabolite: e_0274.
# warning: Adding exchange reaction EX_e_0275 with default bounds for boundary metabolite: e_0275.
# warning: Adding exchange reaction EX_e_0276 with default bounds for boundary metabolite: e_0276.
# warning: Adding exchange reaction EX_e_0277 with default bounds for boundary metabolite: e_0277.
# warning: Adding exchange reaction EX_e_0280 with default bounds for boundary metabolite: e_0280.
# warning: Adding exchange reaction EX_e_0281 with default bounds for boundary metabolite: e_0281.
# warning: Adding exchange reaction EX_e_0282 with default bounds for boundary metabolite: e_0282.
# warning: Adding exchange reaction EX_e_0283 with default bounds for boundary metabolite: e_0283.
# warning: Adding exchange reaction EX_e_0284 with default bounds for boundary metabolite: e_0284.
# warning: Adding exchange reaction EX_e_0285 with default bounds for boundary metabolite: e_0285.
# warning: Adding exchange reaction EX_e_0286 with default bounds for boundary metabolite: e_0286.
# warning: Adding exchange reaction EX_e_0287 with default bounds for boundary metabolite: e_0287.
# warning: Adding exchange reaction EX_e_0288 with default bounds for boundary metabolite: e_0288.
# warning: Adding exchange reaction EX_e_0289 with default bounds for boundary metabolite: e_0289.
# warning: Adding exchange reaction EX_e_0290 with default bounds for boundary metabolite: e_0290.
# warning: Adding exchange reaction EX_e_0291 with default bounds for boundary metabolite: e_0291.
# warning: Adding exchange reaction EX_e_0292 with default bounds for boundary metabolite: e_0292.
# warning: Adding exchange reaction EX_e_0293 with default bounds for boundary metabolite: e_0293.
# warning: Adding exchange reaction EX_e_0294 with default bounds for boundary metabolite: e_0294.
# warning: Adding exchange reaction EX_e_0295 with default bounds for boundary metabolite: e_0295.
# warning: Adding exchange reaction EX_e_0297 with default bounds for boundary metabolite: e_0297.
# warning: Adding exchange reaction EX_e_0298 with default bounds for boundary metabolite: e_0298.
# warning: Adding exchange reaction EX_e_0299 with default bounds for boundary metabolite: e_0299.
# warning: Adding exchange reaction EX_e_0300 with default bounds for boundary metabolite: e_0300.
# warning: Adding exchange reaction EX_e_0301 with default bounds for boundary metabolite: e_0301.
# warning: Adding exchange reaction EX_e_0303 with default bounds for boundary metabolite: e_0303.
# warning: Adding exchange reaction EX_e_0304 with default bounds for boundary metabolite: e_0304.
# warning: Adding exchange reaction EX_e_0305 with default bounds for boundary metabolite: e_0305.
# warning: Adding exchange reaction EX_e_0306 with default bounds for boundary metabolite: e_0306.
# warning: Adding exchange reaction EX_e_0307 with default bounds for boundary metabolite: e_0307.
# warning: Adding exchange reaction EX_e_0308 with default bounds for boundary metabolite: e_0308.
# warning: Adding exchange reaction EX_e_0309 with default bounds for boundary metabolite: e_0309.
# warning: Adding exchange reaction EX_e_0310 with default bounds for boundary metabolite: e_0310.
# warning: Adding exchange reaction EX_e_0311 with default bounds for boundary metabolite: e_0311.
# warning: Adding exchange reaction EX_e_0312 with default bounds for boundary metabolite: e_0312.
# warning: Adding exchange reaction EX_e_0313 with default bounds for boundary metabolite: e_0313.
# warning: Adding exchange reaction EX_e_0314 with default bounds for boundary metabolite: e_0314.
# warning: Adding exchange reaction EX_e_0315 with default bounds for boundary metabolite: e_0315.
# warning: Adding exchange reaction EX_e_0316 with default bounds for boundary metabolite: e_0316.
# warning: Adding exchange reaction EX_e_0317 with default bounds for boundary metabolite: e_0317.
# warning: Adding exchange reaction EX_e_0320 with default bounds for boundary metabolite: e_0320.
# warning: Adding exchange reaction EX_e_0321 with default bounds for boundary metabolite: e_0321.
# warning: Adding exchange reaction EX_e_0322 with default bounds for boundary metabolite: e_0322.
# warning: Adding exchange reaction EX_e_0323 with default bounds for boundary metabolite: e_0323.
# warning: Adding exchange reaction EX_e_0324 with default bounds for boundary metabolite: e_0324.
# warning: Adding exchange reaction EX_e_0325 with default bounds for boundary metabolite: e_0325.
# warning: Adding exchange reaction EX_e_0326 with default bounds for boundary metabolite: e_0326.
# warning: Adding exchange reaction EX_e_0327 with default bounds for boundary metabolite: e_0327.
# warning: Adding exchange reaction EX_e_0328 with default bounds for boundary metabolite: e_0328.
# warning: Adding exchange reaction EX_e_0329 with default bounds for boundary metabolite: e_0329.
# warning: Adding exchange reaction EX_e_0330 with default bounds for boundary metabolite: e_0330.
# warning: Adding exchange reaction EX_e_0331 with default bounds for boundary metabolite: e_0331.
# warning: Adding exchange reaction EX_e_0332 with default bounds for boundary metabolite: e_0332.
# warning: Adding exchange reaction EX_e_0334 with default bounds for boundary metabolite: e_0334.
# warning: Adding exchange reaction EX_e_0335 with default bounds for boundary metabolite: e_0335.
# warning: Adding exchange reaction EX_e_0336 with default bounds for boundary metabolite: e_0336.
# warning: Adding exchange reaction EX_e_0337 with default bounds for boundary metabolite: e_0337.
# warning: Adding exchange reaction EX_e_0338 with default bounds for boundary metabolite: e_0338.
# warning: Adding exchange reaction EX_e_0339 with default bounds for boundary metabolite: e_0339.
# warning: Adding exchange reaction EX_e_0340 with default bounds for boundary metabolite: e_0340.
# warning: Adding exchange reaction EX_e_0341 with default bounds for boundary metabolite: e_0341.
# warning: Adding exchange reaction EX_e_0342 with default bounds for boundary metabolite: e_0342.
# warning: Adding exchange reaction EX_e_0343 with default bounds for boundary metabolite: e_0343.
# warning: Adding exchange reaction EX_e_0344 with default bounds for boundary metabolite: e_0344.
# warning: Adding exchange reaction EX_e_0345 with default bounds for boundary metabolite: e_0345.
# warning: Adding exchange reaction EX_e_0346 with default bounds for boundary metabolite: e_0346.
# warning: Adding exchange reaction EX_e_0347 with default bounds for boundary metabolite: e_0347.
# warning: Adding exchange reaction EX_e_0348 with default bounds for boundary metabolite: e_0348.
# warning: Adding exchange reaction EX_e_0349 with default bounds for boundary metabolite: e_0349.
# warning: Adding exchange reaction EX_e_0350 with default bounds for boundary metabolite: e_0350.
# warning: Adding exchange reaction EX_e_0351 with default bounds for boundary metabolite: e_0351.
# warning: Adding exchange reaction EX_e_0352 with default bounds for boundary metabolite: e_0352.
# warning: Adding exchange reaction EX_e_0353 with default bounds for boundary metabolite: e_0353.
# warning: Adding exchange reaction EX_e_0354 with default bounds for boundary metabolite: e_0354.
# warning: Adding exchange reaction EX_e_0355 with default bounds for boundary metabolite: e_0355.
# warning: Adding exchange reaction EX_e_0356 with default bounds for boundary metabolite: e_0356.
# warning: Adding exchange reaction EX_e_0357 with default bounds for boundary metabolite: e_0357.
# warning: Adding exchange reaction EX_e_0358 with default bounds for boundary metabolite: e_0358.
# warning: Adding exchange reaction EX_e_0359 with default bounds for boundary metabolite: e_0359.
# warning: Adding exchange reaction EX_e_0361 with default bounds for boundary metabolite: e_0361.
# warning: Adding exchange reaction EX_e_0362 with default bounds for boundary metabolite: e_0362.
# warning: Adding exchange reaction EX_e_0363 with default bounds for boundary metabolite: e_0363.
# warning: Adding exchange reaction EX_e_0364 with default bounds for boundary metabolite: e_0364.
# ...
# warning: Adding exchange reaction EX_e_0914 with default bounds for boundary metabolite: e_0914.
# warning: Adding exchange reaction EX_e_0915 with default bounds for boundary metabolite: e_0915.
# warning: Adding exchange reaction EX_e_0916 with default bounds for boundary metabolite: e_0916.
# warning: Adding exchange reaction EX_e_0917 with default bounds for boundary metabolite: e_0917.
# warning: Adding exchange reaction EX_e_0918 with default bounds for boundary metabolite: e_0918.
# warning: Adding exchange reaction EX_e_0919 with default bounds for boundary metabolite: e_0919.
# warning: Adding exchange reaction EX_e_0920 with default bounds for boundary metabolite: e_0920.
# warning: Adding exchange reaction EX_e_0921 with default bounds for boundary metabolite: e_0921.
# warning: Adding exchange reaction EX_e_0922 with default bounds for boundary metabolite: e_0922.
# warning: Adding exchange reaction EX_e_0923 with default bounds for boundary metabolite: e_0923.
# warning: Adding exchange reaction EX_e_0924 with default bounds for boundary metabolite: e_0924.
# warning: Adding exchange reaction EX_e_0925 with default bounds for boundary metabolite: e_0925.
# warning: Adding exchange reaction EX_e_0926 with default bounds for boundary metabolite: e_0926.
# warning: Adding exchange reaction EX_e_0927 with default bounds for boundary metabolite: e_0927.
# warning: Adding exchange reaction EX_e_0928 with default bounds for boundary metabolite: e_0928.
# warning: Adding exchange reaction EX_e_0929 with default bounds for boundary metabolite: e_0929.
# warning: Adding exchange reaction EX_e_0932 with default bounds for boundary metabolite: e_0932.
# warning: Adding exchange reaction EX_e_0933 with default bounds for boundary metabolite: e_0933.
# warning: Adding exchange reaction EX_e_0934 with default bounds for boundary metabolite: e_0934.
# warning: Adding exchange reaction EX_e_0935 with default bounds for boundary metabolite: e_0935.
# warning: Adding exchange reaction EX_e_0936 with default bounds for boundary metabolite: e_0936.
# warning: Adding exchange reaction EX_e_0937 with default bounds for boundary metabolite: e_0937.
# warning: Adding exchange reaction EX_e_0938 with default bounds for boundary metabolite: e_0938.
# warning: Adding exchange reaction EX_e_0939 with default bounds for boundary metabolite: e_0939.
# warning: Adding exchange reaction EX_e_0940 with default bounds for boundary metabolite: e_0940.
# warning: Adding exchange reaction EX_e_0941 with default bounds for boundary metabolite: e_0941.
# warning: Adding exchange reaction EX_e_0942 with default bounds for boundary metabolite: e_0942.
# warning: Adding exchange reaction EX_e_0943 with default bounds for boundary metabolite: e_0943.
# warning: Adding exchange reaction EX_e_0944 with default bounds for boundary metabolite: e_0944.
# warning: Adding exchange reaction EX_e_0945 with default bounds for boundary metabolite: e_0945.
# warning: Adding exchange reaction EX_e_0946 with default bounds for boundary metabolite: e_0946.
# warning: Adding exchange reaction EX_e_0947 with default bounds for boundary metabolite: e_0947.
# warning: Adding exchange reaction EX_e_0948 with default bounds for boundary metabolite: e_0948.
# warning: Adding exchange reaction EX_e_0949 with default bounds for boundary metabolite: e_0949.
# warning: Adding exchange reaction EX_e_0950 with default bounds for boundary metabolite: e_0950.
# warning: Adding exchange reaction EX_e_0951 with default bounds for boundary metabolite: e_0951.
# warning: Adding exchange reaction EX_e_0952 with default bounds for boundary metabolite: e_0952.
# warning: Adding exchange reaction EX_e_0953 with default bounds for boundary metabolite: e_0953.
# warning: Adding exchange reaction EX_e_0954 with default bounds for boundary metabolite: e_0954.
# warning: Adding exchange reaction EX_e_0955 with default bounds for boundary metabolite: e_0955.
# warning: Adding exchange reaction EX_e_0956 with default bounds for boundary metabolite: e_0956.
# warning: Adding exchange reaction EX_e_0957 with default bounds for boundary metabolite: e_0957.
# warning: Adding exchange reaction EX_e_0958 with default bounds for boundary metabolite: e_0958.
# warning: Adding exchange reaction EX_e_0959 with default bounds for boundary metabolite: e_0959.
# warning: Adding exchange reaction EX_e_0960 with default bounds for boundary metabolite: e_0960.
# warning: Adding exchange reaction EX_e_0961 with default bounds for boundary metabolite: e_0961.
# warning: Adding exchange reaction EX_e_0962 with default bounds for boundary metabolite: e_0962.
# warning: Adding exchange reaction EX_e_0963 with default bounds for boundary metabolite: e_0963.
# warning: Adding exchange reaction EX_e_0966 with default bounds for boundary metabolite: e_0966.
# warning: Adding exchange reaction EX_e_0967 with default bounds for boundary metabolite: e_0967.
# warning: Adding exchange reaction EX_e_0968 with default bounds for boundary metabolite: e_0968.
# warning: Adding exchange reaction EX_e_0970 with default bounds for boundary metabolite: e_0970.
# warning: Adding exchange reaction EX_e_0971 with default bounds for boundary metabolite: e_0971.
# warning: Adding exchange reaction EX_e_0972 with default bounds for boundary metabolite: e_0972.
# warning: Adding exchange reaction EX_e_0973 with default bounds for boundary metabolite: e_0973.
# warning: Adding exchange reaction EX_e_0974 with default bounds for boundary metabolite: e_0974.
# warning: Adding exchange reaction EX_e_0975 with default bounds for boundary metabolite: e_0975.
# warning: Adding exchange reaction EX_e_0976 with default bounds for boundary metabolite: e_0976.
# warning: Adding exchange reaction EX_e_0977 with default bounds for boundary metabolite: e_0977.
# warning: Adding exchange reaction EX_e_0978 with default bounds for boundary metabolite: e_0978.
# warning: Adding exchange reaction EX_e_0979 with default bounds for boundary metabolite: e_0979.
# warning: Adding exchange reaction EX_e_0980 with default bounds for boundary metabolite: e_0980.
# warning: Adding exchange reaction EX_e_0981 with default bounds for boundary metabolite: e_0981.
# warning: Adding exchange reaction EX_e_0982 with default bounds for boundary metabolite: e_0982.
# warning: Adding exchange reaction EX_e_0983 with default bounds for boundary metabolite: e_0983.
# warning: Adding exchange reaction EX_s_2765 with default bounds for boundary metabolite: s_2765.
# warning: Adding exchange reaction EX_s_2767 with default bounds for boundary metabolite: s_2767.
# warning: Adding exchange reaction EX_e_0984 with default bounds for boundary metabolite: e_0984.
# warning: Adding exchange reaction EX_e_0985 with default bounds for boundary metabolite: e_0985.
# warning: Adding exchange reaction EX_e_0986 with default bounds for boundary metabolite: e_0986.
# warning: Adding exchange reaction EX_e_0987 with default bounds for boundary metabolite: e_0987.
# warning: Adding exchange reaction EX_e_0988 with default bounds for boundary metabolite: e_0988.
# warning: Adding exchange reaction EX_e_0989 with default bounds for boundary metabolite: e_0989.
# warning: Adding exchange reaction EX_e_0990 with default bounds for boundary metabolite: e_0990.
# warning: Adding exchange reaction EX_e_0991 with default bounds for boundary metabolite: e_0991.
# warning: Adding exchange reaction EX_e_0992 with default bounds for boundary metabolite: e_0992.
# warning: Adding exchange reaction EX_s_2823 with default bounds for boundary metabolite: s_2823.
# warning: Adding exchange reaction EX_s_2825 with default bounds for boundary metabolite: s_2825.
# warning: Adding exchange reaction EX_s_2827 with default bounds for boundary metabolite: s_2827.
# warning: Adding exchange reaction EX_s_2830 with default bounds for boundary metabolite: s_2830.
# warning: Adding exchange reaction EX_e_0993 with default bounds for boundary metabolite: e_0993.
# warning: Adding exchange reaction EX_e_0994 with default bounds for boundary metabolite: e_0994.
# warning: Adding exchange reaction EX_e_0995 with default bounds for boundary metabolite: e_0995.
# warning: Adding exchange reaction EX_e_0996 with default bounds for boundary metabolite: e_0996.
# warning: Adding exchange reaction EX_e_0997 with default bounds for boundary metabolite: e_0997.
# warning: Adding exchange reaction EX_e_0998 with default bounds for boundary metabolite: e_0998.
# warning: Adding exchange reaction EX_e_0999 with default bounds for boundary metabolite: e_0999.
# warning: Adding exchange reaction EX_e_1000 with default bounds for boundary metabolite: e_1000.
# warning: Adding exchange reaction EX_e_1001 with default bounds for boundary metabolite: e_1001.
# warning: Adding exchange reaction EX_e_1002 with default bounds for boundary metabolite: e_1002.
# warning: Adding exchange reaction EX_e_1003 with default bounds for boundary metabolite: e_1003.
# warning: Adding exchange reaction EX_e_1004 with default bounds for boundary metabolite: e_1004.
# warning: Adding exchange reaction EX_e_1005 with default bounds for boundary metabolite: e_1005.
# warning: Adding exchange reaction EX_e_1006 with default bounds for boundary metabolite: e_1006.
# warning: Adding exchange reaction EX_e_1007 with default bounds for boundary metabolite: e_1007.
# warning: Adding exchange reaction EX_e_1008 with default bounds for boundary metabolite: e_1008.
# warning: Adding exchange reaction EX_e_1009 with default bounds for boundary metabolite: e_1009.
# warning: Adding exchange reaction EX_e_1010 with default bounds for boundary metabolite: e_1010.
# warning: Adding exchange reaction EX_e_1011 with default bounds for boundary metabolite: e_1011.
# warning: Adding exchange reaction EX_e_1012 with default bounds for boundary metabolite: e_1012.
# warning: Adding exchange reaction EX_e_1013 with default bounds for boundary metabolite: e_1013.
# warning: Adding exchange reaction EX_e_1014 with default bounds for boundary metabolite: e_1014.
# warning: Adding exchange reaction EX_e_1015 with default bounds for boundary metabolite: e_1015.
# warning: Adding exchange reaction EX_e_1016 with default bounds for boundary metabolite: e_1016.
# warning: Adding exchange reaction EX_e_1017 with default bounds for boundary metabolite: e_1017.
# warning: Adding exchange reaction EX_e_1018 with default bounds for boundary metabolite: e_1018.
# warning: Adding exchange reaction EX_e_1019 with default bounds for boundary metabolite: e_1019.
# warning: Adding exchange reaction EX_e_1020 with default bounds for boundary metabolite: e_1020.
# warning: Adding exchange reaction EX_e_1021 with default bounds for boundary metabolite: e_1021.
# warning: Adding exchange reaction EX_e_1022 with default bounds for boundary metabolite: e_1022.
# warning: Adding exchange reaction EX_e_1023 with default bounds for boundary metabolite: e_1023.
# warning: Adding exchange reaction EX_e_1024 with default bounds for boundary metabolite: e_1024.
# warning: Adding exchange reaction EX_e_1025 with default bounds for boundary metabolite: e_1025.
# warning: Adding exchange reaction EX_e_1026 with default bounds for boundary metabolite: e_1026.
# warning: Adding exchange reaction EX_e_1027 with default bounds for boundary metabolite: e_1027.
# warning: Adding exchange reaction EX_e_1028 with default bounds for boundary metabolite: e_1028.
# warning: Adding exchange reaction EX_e_1029 with default bounds for boundary metabolite: e_1029.
# warning: Adding exchange reaction EX_e_1030 with default bounds for boundary metabolite: e_1030.
# warning: Adding exchange reaction EX_e_1031 with default bounds for boundary metabolite: e_1031.
# warning: Adding exchange reaction EX_e_1032 with default bounds for boundary metabolite: e_1032.
# warning: Adding exchange reaction EX_e_1033 with default bounds for boundary metabolite: e_1033.
# warning: Adding exchange reaction EX_e_1034 with default bounds for boundary metabolite: e_1034.
# warning: Adding exchange reaction EX_e_1035 with default bounds for boundary metabolite: e_1035.
# warning: Adding exchange reaction EX_e_1036 with default bounds for boundary metabolite: e_1036.
# warning: Adding exchange reaction EX_e_1037 with default bounds for boundary metabolite: e_1037.
# warning: Adding exchange reaction EX_e_1038 with default bounds for boundary metabolite: e_1038.
# warning: Adding exchange reaction EX_e_1039 with default bounds for boundary metabolite: e_1039.
# warning: Adding exchange reaction EX_e_1040 with default bounds for boundary metabolite: e_1040.
# warning: Adding exchange reaction EX_e_1041 with default bounds for boundary metabolite: e_1041.
# warning: Adding exchange reaction EX_e_1042 with default bounds for boundary metabolite: e_1042.
# warning: Adding exchange reaction EX_e_1043 with default bounds for boundary metabolite: e_1043.
# warning: Adding exchange reaction EX_e_1044 with default bounds for boundary metabolite: e_1044.
# warning: Adding exchange reaction EX_e_1045 with default bounds for boundary metabolite: e_1045.
# warning: Adding exchange reaction EX_e_1046 with default bounds for boundary metabolite: e_1046.
# warning: Adding exchange reaction EX_e_1047 with default bounds for boundary metabolite: e_1047.
# warning: Adding exchange reaction EX_e_1048 with default bounds for boundary metabolite: e_1048.
# warning: Adding exchange reaction EX_e_1049 with default bounds for boundary metabolite: e_1049.
# warning: Adding exchange reaction EX_e_1050 with default bounds for boundary metabolite: e_1050.
# warning: Adding exchange reaction EX_e_1051 with default bounds for boundary metabolite: e_1051.
# warning: Adding exchange reaction EX_s_1796 with default bounds for boundary metabolite: s_1796.
# warning: Adding exchange reaction EX_s_3717 with default bounds for boundary metabolite: s_3717.
# warning: Adding exchange reaction EX_s_3718 with default bounds for boundary metabolite: s_3718.
# warning: Adding exchange reaction EX_e_1053 with default bounds for boundary metabolite: e_1053.
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.5, pytest-4.6.11, py-1.10.0, pluggy-0.13.1
# rootdir: /Users/s143838/courses/course-materials
# plugins: anyio-3.3.1
# collected 146 items / 1 skipped / 145 selected
#
# ../.venv_cellfactories/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py . [  0%]
# .FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF.FFF.FFFFFF.FFFFFFFFFFFFFFFFF..         [ 44%]
# ../.venv_cellfactories/lib/python3.8/site-packages/memote/suite/tests/test_basic.py . [ 45%]
# F....FFF.F....FFF.F..F                                                   [ 60%]
# ../.venv_cellfactories/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py . [ 60%]
# F....FF.F                                                                [ 67%]
# ../.venv_cellfactories/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py s [ 67%]
# FFssssssssssssssss.FFFFF.ssF                                             [ 86%]
# ../.venv_cellfactories/lib/python3.8/site-packages/memote/suite/tests/test_essentiality.py s [ 87%]
#                                                                          [ 87%]
# ../.venv_cellfactories/lib/python3.8/site-packages/memote/suite/tests/test_growth.py s [ 88%]
#                                                                          [ 88%]
# ../.venv_cellfactories/lib/python3.8/site-packages/memote/suite/tests/test_matrix.py . [ 89%]
# ...                                                                      [ 91%]
# ../.venv_cellfactories/lib/python3.8/site-packages/memote/suite/tests/test_sbml.py . [ 91%]
# .                                                                        [ 92%]
# ../.venv_cellfactories/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py F [ 93%]
# FsFFFsFssF                                                               [100%]
#
# ============== 87 failed, 34 passed, 26 skipped in 88.34 seconds ===============
# Writing snapshot report to 'yeast_7.6.html'.
# CPU times: user 2 s, sys: 633 ms, total: 2.64 s
# Wall time: 1min 42s
